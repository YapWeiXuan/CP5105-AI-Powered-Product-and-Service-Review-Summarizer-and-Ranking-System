# %%
import os
import httpx
import pandas as pd
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request
import requests
import numpy as np
import import_ipynb
import ollama
from evaluate import load
from rouge import Rouge

# %%
import import_ipynb
import importlib
import Eval_Metrics
eval_metrics = Eval_Metrics.Evaluation_Metrics()
# importlib.reload(Eval_Metrics)
# eval_metrics = Eval_Metrics.Evaluation_Metrics()

# %% [markdown]
# ### Getting Ranking List Prompt Dataset to be used in Ranking List LLM Evaluation

# %%
prompt_examples_df = pd.read_excel(r"C:\Users\flame\CP5105-AI-Powered-Product-and-Service-Review-Summarizer-and-Ranking-System\BackEnd\All Prompt Examples\Ranking List Prompt Dataset.xlsx")

# %%
prompt_examples_df['Modified_Multiple_Generated_Summaries'] = prompt_examples_df['Modified_Multiple_Generated_Summaries'].map(lambda a: a.replace('\n',' '))

# %%
prompt_examples_df.columns
# Out:
# Index(['Query', 'Modified_1_Generated_Summary',
#        'Modified_Multiple_Generated_Summaries', 'Model_Ranking_List_Output',
#        'Model_Ranking_List_for_Manual_Checking', 'Prompt', 'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# #### Getting Data to be used as Prompt Examples from dataset

# %%
promptengin_df = prompt_examples_df[prompt_examples_df['Prompt']=='Use for Prompt'].reset_index(drop=True)
promptengin_df
# Out:
#                                                Query  \
# 0  What are the worst mobile phone games released...
# 1  What are the top 5 best sci-fi movies of all t...
# 2   What are the 3 worst games consoles of all time?
# 3                  What are the 5 worst board games?
# 4          What are the best printer models in 2024?
#
#                         Modified_1_Generated_Summary  \
# 0  The gaming industry has been flooded with new ...
# 1  This is a question that has been debated by fi...
# 2  The Atari Jaguar is often cited as one of the ...
# 3  Determining the worst board games can be subje...
# 4  Choosing the right printer can be overwhelming...
#
#                Modified_Multiple_Generated_Summaries  \
# 0  Article #1: The gaming industry has been flood...
# 1  Article #1:  This is a question that has been ...
# 2  Article #1:  The Atari Jaguar is often cited a...
# 3  Article #1: Determining the worst board games ...
# 4  Article #1: Choosing the right printer can be ...
#
#                            Model_Ranking_List_Output  \
# 0  Here is the ranking list for the worst mobile ...
# 1  Here is the ranking list for the top 5 best sc...
# 2  Here is the ranking list for the 3 worst games...
# 3  Here is the ranking list for the 5 worst board...
# 4  Here is the ranking list for the best printer ...
#
#               Model_Ranking_List_for_Manual_Checking          Prompt  \
# 0  1: Robot Rebellion\n2. Galactic Conquest\nRest...  Use for Prompt
# 1  1: Blade Runner\n2: The Matrix\n3: A Space Ody...  Use for Prompt
# 2  1,2: Atari Jaguar, Nintendo Virtual Boy\n3: Se...  Use for Prompt
# 3  1: Monikers\n2: Don’t Wake Daddy\n3: Battleshi...  Use for Prompt
# 4  1. Epson Expression Photo HD XP-15000\n2. Xero...  Use for Prompt
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# #### Getting Data to be used for Ranking List LLM testing from dataset

# %%
testprompt_df = prompt_examples_df[prompt_examples_df['Prompt'].isna()==True].reset_index(drop=True)
testprompt_df
# Out:
#                                                Query  \
# 0               What are the top car models in 2024?
# 1        What are the 3 worst laptop brands in 2024?
# 2  What are the cheapest but decent laptop models...
# 3                 What are the top sunscreen brands?
# 4  What are the most interesting and top rated bo...
# 5  What are the most hated and worst books releas...
# 6    What are the 5 worst horror movies of all time?
# 7    What are the 3 best games consoles of all time?
# 8      What are the 5 best board games for children?
# 9          What are the worst mobile phones in 2024?
#
#                         Modified_1_Generated_Summary  \
# 0  The automotive industry is constantly evolving...
# 1  The ranking of laptop brands can vary dependin...
# 2  When it comes to budget-friendly laptops, ther...
# 3  Sunscreen is a vital part of our daily skincar...
# 4  The year 2024 is expected to bring a diverse r...
# 5  Based on user ratings on Goodreads, some of th...
# 6  The assessment of the worst horror movies is s...
# 7  Determining the "best" gaming consoles is subj...
# 8  Choosing the right board game can be a challen...
# 9  The ranking of the worst mobile phones can be ...
#
#                Modified_Multiple_Generated_Summaries  \
# 0  Article #1: The automotive industry is constan...
# 1  Article #1: The ranking of laptop brands can v...
# 2  Article #1: When it comes to budget-friendly l...
# 3  Article #1:  Sunscreen is a vital part of our ...
# 4  Article #1: The year 2024 is expected to bring...
# 5  Article #1: Based on user ratings on Goodreads...
# 6  Article #1: The assessment of the worst horror...
# 7  Article #1: Determining the "best" gaming cons...
# 8  Article #1: Choosing the right board game can ...
# 9  Article #1: The ranking of the worst mobile ph...
#
#                            Model_Ranking_List_Output  \
# 0  Here is the ranking list for the top car model...
# 1  Here is the ranking list for the 3 worst lapto...
# 2  Here is the ranking list for the top budget la...
# 3  Here is the ranking list for the top sunscreen...
# 4  Here is the ranking list for the most interest...
# 5  Here is the ranking list for the most hated an...
# 6  Here is the ranking list for the 5 worst horro...
# 7  Here is the ranking list for the top 3 best ga...
# 8  Here is the ranking list for the 5 best board ...
# 9  Here is the ranking list for the worst mobile ...
#
#               Model_Ranking_List_for_Manual_Checking Prompt  \
# 0  1,2: Toyota Camry , Honda Civic Type R\n3,4: H...    NaN
# 1                        1: Acer\n2: Lenovo\n3: Asus    NaN
# 2  1: Lenovo IdeaPad 330S\n2,3, 4 ,5: Acer Aspire...    NaN
# 3  1. Neutrogena\n2. Hawaiian Tropic\n3,4,5: La R...    NaN
# 4  1,2: The It Girl, The Memory Keeper\'s Daughte...    NaN
# 5  1,2: No Going Back , Crown of Starlight\n3,4 :...    NaN
# 6  1: Devil\n2: Birdemic: Shock and Terror (2010)...    NaN
# 7  1,2: PlayStation 2 (PS2) , Nintendo Entertainm...    NaN
# 8  1,2,3,4 : Candy Land, Chutes and Ladders, Mono...    NaN
# 9  1. Motorola Defy Pro X\n2,3: HTC One M7, Samsu...    NaN
#
#                                           Unnamed: 6
# 0               What are the top car models in 2024?
# 1        What are the 3 worst laptop brands in 2024?
# 2  What are the cheapest but decent laptop models...
# 3                 What are the top sunscreen brands?
# 4  What are the most interesting and top rated bo...
# 5  What are the most hated and worst books releas...
# 6    What are the 5 worst horror movies of all time?
# 7    What are the 3 best games consoles of all time?
# 8      What are the 5 best board games for children?
# 9          What are the worst mobile phones in 2024?

# %% [markdown]
# #### Ranking List response generation function for SLT text input

# %%
def MULTI_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt
        },
        {
            'role': 'user',
            'content': f'In the context of "{query}" , generate an ordered and ranked list from the following ARTICLEs: ' 
            + text,
        },
        # {
        #     'role': 'assistant',
        #     'content': f'{query}'     
        # }
        ]
        # options={
        #     'temperature':0.1
        # }
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# #### Ranking List response generation function for Zero Shot COT (Process Logic in User role) SCT text input

# %%
def ZERO_STEP_USER_COT_SINGLE_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt
        },
        {
            'role': 'user',
            'content': f''' Let\'s think step by step.
            1) Identify the item names relevant to the {query} in the user prompt text.
            2) Calculate number of times each item name is mentioned in the user prompt text.
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            4) Provide a description for each item name in the ordered ranking list.
            
            Now, in the context of "{query}" , generate an ordered and ranked list from the following text : '''
            + text,
        },

        ]
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# #### Ranking List response generation function for Zero Shot COT (Process Logic in System role) SCT text input

# %%
# SINGLE_generate_report_with_query
def ZERO_STEP_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt + f'''
            Let\'s think step by step.
            1) Identify the item names relevant to the {query} in the user prompt text.
            2) Calculate number of times each item name is mentioned in the user prompt text.
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            4) Provide a description for each item name in the ordered ranking list.
            '''
        },
        {
            'role': 'user',
            'content': f'''In the context of "{query}" , generate an ordered and ranked list from the following text : '''
            + text,
        },

        ]
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# #### Ranking List response generation function for Zero Shot COT (Process Logic in Assistant role) SCT text input

# %%
# SINGLE_generate_report_with_query
def ZERO_STEP_ASST_COT_SINGLE_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt
        },
        {
            'role': 'user',
            'content': f''' In the context of "{query}" , generate an ordered and ranked list from the following text : '''
            + text,
        },
        {
            'role': 'assistant',
            'content': f''' Let\'s think step by step.
            1) Identify the item names relevant to the {query} in the user prompt text.
            2) Calculate number of times each item name is mentioned in the user prompt text.
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            4) Provide a description for each item name in the ordered ranking list.
            '''
        }

        ]
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# #### Ranking List response generation function for Zero Shot COT (No Process Logic) SCT text input

# %%
def ZERO_NO_STEPS_COT_SINGLE_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt
        },
        {
            'role': 'user',
            'content': f''' Let\'s think step by step. In the context of "{query}" , generate an ordered and ranked list from the following text : '''
            + text,
        },

        ]
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# #### Ranking List response generation function for Few (3) Shot COT (Process Logic in System Role) (Prompt Examples in System Logic) SCT text input

# %%
def ZERO_STEP_WITH_EX_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt):
               

    
    response = ollama.chat(
        model=model, 
        messages=[
        {
            'role': 'system',
            'content': prompt + f'''
            Let\'s think step by step.
            1) Identify the item names relevant to the {query} in the user prompt text.
            2) Calculate number of times each item name is mentioned in the user prompt text.
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            4) Provide a description for each item name in the ordered ranking list.
            
            Your answer should follow the same logic as the example prompts and responses encapsulated in the <EXAMPLE> , </EXAMPLE> tags.
            ---\
            <EXAMPLE>\
            Prompt: In the context of "What are the 3 worst games consoles of all time?" , generate an ordered and ranked list from the following text input: The Atari Jaguar is often cited as one of the most disappointing consoles ever made, with its high price and lackluster lineup of games failing to attract a significant audience.  The Sega Dreamcast was another console that failed to gain traction in the market, despite its innovative controller design and online capabilities. Its short lifespan and limited support from third-party developers also contributed to its failure. The console is still remembered fondly by some enthusiasts for its quirky charm and exclusive games such as Sonic Adventure and Crazy Taxi.  The Nintendo Virtual Boy is widely regarded as one of the worst consoles ever made, with its poor graphics, lackluster lineup of games, and high price point making it a flop in the market. The console's failure was so severe that it led to a significant decline in Nintendo's stock value and a reevaluation of their hardware design strategies.  The Atari 7800 is another console often cited as one of the worst due to its poor design and lackluster lineup of games, with many critics feeling that it was little more than an improved version of the Atari 2600. The console's high price point and limited support from third-party developers also contributed to its failure in the market.  The Sega Nomad is often cited as one of the worst handheld consoles ever made due to its poor battery life, lackluster lineup of games, and high price point. Its design flaws and limited functionality made it unpopular among gamers, leading to a significant decline in sales for Sega.  The Nintendo 64DD was another console that failed to gain traction in the market, with its slow loading times, limited support from third-party developers, and lackluster lineup of games making it unpopular among gamers. Its short lifespan and poor marketing also contributed to its failure, ultimately leading to a loss for Nintendo.  The Sega SG-1000 is often cited as one of the worst consoles ever made due to its poor design, lackluster lineup of games, and high price point. Its limited functionality and compatibility issues made it unpopular among gamers, leading to a significant decline in sales for Sega.  Each of these consoles has been remembered fondly by some enthusiasts for their quirks and charm, but overall they are widely regarded as some of the worst consoles ever made due to their poor design, lackluster lineups of games, and limited functionality.
            When evaluating the worst gaming consoles ever made, it's essential to consider several factors such as their technical issues, poor game library, and overall impact on the gaming industry.  One of the worst consoles is the Sega Dreamcast released in 1998. Although it received widespread critical acclaim for its innovative design and impressive games like Sonic Adventure and Crazy Taxi, it struggled financially due to a lack of third-party support and limited release in various countries. This led to a significant decline in sales, ultimately causing the console's demise.  Another contender is the Nintendo Virtual Boy released in 1995. Although touted as the successor to the Super Nintendo, this console failed miserably due to its poor game library and numerous technical issues. Its games were often criticized for their low resolution and lackluster graphics, which further exacerbated the console's failure.  Lastly, the Atari Jaguar, released in 1993, is also considered one of the worst consoles ever made. Despite being launched with significant hype, it suffered from a limited game library and numerous technical issues such as overheating and poor sound quality. Its failure was so catastrophic that it nearly bankrupted the company, leading to a massive decline in its market value.  The three consoles were unable to gain substantial market share or even stay afloat for an extended period. While some may argue that their failures led to improvements in future gaming technology and innovations, they undoubtedly remain among the worst console releases in history.
            The Atari Jaguar, Sega Saturn, and Nintendo Virtual Boy have been widely regarded as some of the worst game consoles ever released.  The Atari Jaguar was released in 1993 and failed miserably due to its high price tag, poor marketing, and lackluster library of games. It had a short lifespan, lasting only three years before being discontinued. The console's failure was attributed to its inability to compete with other popular consoles such as the Sega Genesis and Super Nintendo Entertainment System.  The Sega Saturn, released in 1994, was plagued by poor marketing and high development costs. Despite its impressive graphics capabilities, it failed to gain significant market share due to its limited game library and lack of third-party support. The console's failure led to a significant decline in Sega's fortunes, resulting in the company eventually abandoning the Saturn and shifting focus to other ventures.  The Nintendo Virtual Boy was released in 1995 as a pioneering attempt at virtual reality gaming but ultimately failed due to its high price, lackluster library of games, and limited lifespan. The console was criticized for its poor graphics, awkward design, and lack of appeal to mainstream gamers. Its failure led to Nintendo abandoning the concept of virtual reality gaming for several years.  In conclusion, these three consoles are often cited as some of the worst game consoles ever released due to their high prices, poor marketing, and limited libraries of games.
            \
            Response: 
            1) Identify the item names relevant to the {query} in the user prompt text. Identified items: Atari Jaguar , Sega Dreamcast , Nintendo Virtual Boy , Atari 7800 , Sega Nomad , Nintendo 64DD , Sega SG-1000 , The Sega Saturn
            
            2) Calculate number of times each item name is mentioned in the user prompt text. Atari Jaguar appeared 4 times, Sega Dreamcast appeared 2 times, Nintendo Virtual Boy appeared 4 times, Atari 7800 appeared 1 time, Sega Nomad appeared 1 time, Nintendo 64DD appeared 1 time, Sega SG-1000 appeared 1 time, Sega Saturn appeared 2 times
            
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            Here is the ranking list for the 3 worst games consoles of all time with their summaries from the most to least bad:
            \n
            **#1. Atari Jaguar:**
            \n
            **#2. Nintendo Virtual Boy:**
            \n
            **#3. Sega Dreamcast:**
            
            4) Provide a description for each item name in the ordered ranking list.
            Here is the ranking list for the 3 worst games consoles of all time with their summaries from the most to least bad:
            \n
            **#1. Atari Jaguar:**
            The Atari Jaguar is widely regarded as one of the most disappointing consoles ever made, released in 1993 with high hopes but ultimately failing due to a combination of factors including its high price tag, limited game library, and numerous technical issues. Its catastrophic failure nearly bankrupted the company and led to a significant decline in market value, forcing the console's discontinuation just three years after its release.
            \n
            **#2. Nintendo Virtual Boy:**
            The Nintendo Virtual Boy is widely regarded as one of the worst consoles ever made due to its poor graphics, limited game library, and high price point, which ultimately led to a significant decline in Nintendo's stock value and a reevaluation of their hardware design strategies. Released in 1995 as an attempt at virtual reality gaming, the console failed miserably due to its numerous technical issues, awkward design, and lack of appeal to mainstream gamers, causing Nintendo to abandon the concept of virtual reality gaming for several years.
y named Elliott who befriends an alien who has been left behind on Earth and must help him return home.  The Matrix (1999) is another influential sci-fi movie that redefined the genre with its innovative special effects, intricate storyline, and thought-provoking themes. Directed by the Wachowskis, this movie follows a computer hacker named Neo who discovers that his entire life has been a simulated reality created by sentient machines to distract humans while their bodies are harvested for energy.  These five movies have all had a significant impact on popular culture and continue to be widely discussed and debated by fans of science fiction. While opinions may vary, they are generally regarded as some of the greatest sci-fi films of all time due to their thought-provoking themes, visually stunning cinematography, and enduring influence on the genre.  In conclusion, these five movies have captured the imagination of audiences worldwide with their complex characters, engaging storylines, and exploration of deeper themes. They continue to be celebrated as some of the greatest sci-fi films of all time and remain essential viewing for fans of science fiction and anyone interested in exploring new ideas and perspectives.
            \
            Response: 
            1) Identify the item names relevant to the {query} in the user prompt text. Identified items: Blade Runner , The Matrix ,  2001: A Space Odyssey ,  Alien (1979) , The Last Jedi , Inception , Star Wars: Episode IV - A New Hope , E.T., the Extra-Terrestrial
            
            2) Calculate number of times each item name is mentioned in the user prompt text. Blade Runner appeared 8 times , The Matrix appeared 6 times,  2001: A Space Odyssey appeared 4 times,  Alien (1979) appeared 2 times , The Last Jedi appeared 1 time , Inception appeared 1 time , Star Wars: Episode IV - A New Hope appeared 1 time , E.T., the Extra-Terrestrial appeared 1 time.
            
            
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            Here is the ranking list for the top 5 best sci-fi movies of all time with their summaries from most to least:
            \n
            **#1. Blade Runner:**
            \n
            **#2. The Matrix: **
            \n
            **#3. 2001: A Space Odyssey: **
            \n
            **#4. Alien (1979): **
            \n
            **#5. The Last Jedi: **
            
            4) Provide a description for each item name in the ordered ranking list.
            
            Here is the ranking list for the top 5 best sci-fi movies of all time with their summaries from most to least:
            \n
            **#1. Blade Runner:**
            'Blade Runner, directed by Ridley Scott in 1982, is a groundbreaking and thought-provoking sci-fi classic that explores complex themes about humanity, identity, and what it means to be alive. Set in a dystopian future where synthetic beings known as replicants are hunted by special police officers called blade runners, the film delves into questions about artificial intelligence, empathy, and humanity through its atmospheric visuals, rich themes, and memorable characters, ultimately becoming a cult classic among sci-fi fans that has influenced numerous other movies and TV shows.'
            \n
            **#2. The Matrix: **
            'The Matrix (1999), directed by the Wachowskis, is an iconic and influential sci-fi movie that revolutionized visual effects with its "bullet time" sequences and "green screen" work. The film tells the story of Neo, a computer hacker who discovers his life has been simulated within a virtual reality program created by intelligent machines to subdue humanity, forcing him to choose between loyalty to humans and connection with the machines. With its innovative special effects, intricate storyline, and thought-provoking themes, The Matrix is widely regarded as one of the greatest sci-fi films ever made, redefining the genre with its groundbreaking storytelling and visuals.'
            \n
            **#3. 2001: A Space Odyssey: **
            "Stanley Kubrick's 2001: A Space Odyssey (1968) is widely regarded as one of the greatest films of all time and has had a profound influence on popular culture, particularly in the science fiction genre. The film follows a team of astronauts on a mission to Jupiter who encounter a mysterious alien monolith that holds the key to humanity's evolution and destiny, prompting them to confront their own existence and the possibility of extraterrestrial life. With its groundbreaking special effects, philosophical themes, and enigmatic ending, 2001: A Space Odyssey continues to inspire new generations of filmmakers and sci-fi enthusiasts with its thought-provoking exploration of human evolution, technology, and existentialism."
" has also received criticism for its often-dull gameplay and reliance on luck. Players take turns trying to guess the name of a movie, book, or other item based on a brief description provided by another player. However, Monikers\' popularity can be attributed to its social aspect rather than its gameplay mechanics. The game "Monikers" has been criticized for its dull and luck-based gameplay, where players try to guess the name of an item based on a brief description, but its popularity is actually driven by its social interaction aspect, making it enjoyable despite its shortcomings in terms of gameplay. It is essential to note that opinions on board games are highly subjective, and what one person considers to be among the worst may not resonate with another. Additionally, personal experiences and preferences can greatly influence how enjoyable or frustrating a game is. Ultimately, it's up to individual gamers to decide which games they enjoy playing and which ones they prefer to avoid.
            \
            Response: 
            1) Identify the item names relevant to the {query} in the user prompt text. Identified items: Monikers , Don\'t Wake Daddy , Battleship , Pictionary , Taboo , Angry Birds (2012) , Cootie (1966) , Afrikan T hti (1975) , Ungame (1979) , Uncle Wiggily's Adventures (1966) , Don't Break the Ice , Cranium  , Mall Madness , Bop It!.
            
            2) Calculate number of times each item name is mentioned in the user prompt text. Monikers appeared 8 times , Don\'t Wake Daddy appeared 6 times , Battleship appeared 4 times , Pictionary appeared 5 times , Taboo appeared 2 times , Angry Birds (2012) appeared 1 time , Cootie (1966) appeared 1 time , Afrikan T hti (1975) appeared 1 time , Ungame (1979) appeared 1 time , Uncle Wiggily's Adventures (1966) appeared 1 time , Don't Break the Ice appeared 1 time , Cranium appeared 2 times  , Mall Madness appeared 1 time , Bop It! appeared 2 times.
            
            3) Create an ordered ranking list ordered from item name that appeared most amount of times in the user prompt text to the item name that appeared least amount of times in the user prompt text.
            Here is the ranking list for the 5 worst board games with their summaries from the most to least bad: 
            \n
            **#1. Monikers:**
            \n
            **#2. Don\'t Wake Daddy:**
            \n
            **#3. Battleship:**
            \n
            **#4. Pictionary:**
            \n
            **#5. Taboo:**
            
            4) Provide a description for each item name in the ordered ranking list.
            Here is the ranking list for the 5 worst board games with their summaries from the most to least bad: 
            \n
            **#1. Monikers:**
            The board game "Monikers" has been criticized for its dull and luck-based gameplay, but it remains popular due to its social aspect, where players participate in guessing the name of a movie, book, or item based on brief descriptions provided by others.
            \n
            **#2. Don\'t Wake Daddy:**
            The game "Don\'t Wake Daddy" is often considered one of the worst games ever made, released in 1999 by Playmonster Games, due to its poorly executed unique premise and lackluster gameplay. Players must navigate through a dark room filled with obstacles while attempting not to wake up the character known as "Daddy".
            \n
            **#3. Battleship:**
            Battleship, released by Milton Bradley (now Hasbro) in 1967, has been widely criticized for its basic gameplay and grid-based mechanics, which rely too heavily on chance rather than strategy.
            \n
            **#4. Pictionary:**
            Pictionary is often viewed as an unenjoyable board game because of its straightforward nature and emphasis on artistic skill, leading to a shallow experience due to its simplicity and limited strategic gameplay options.
            \n
            **#5. Taboo:**
            The board game "Taboo" has been criticized for its chaotic gameplay and lack of strategic thinking, as it relies heavily on speed and luck, often resulting in confusion and frustration among players.
            \n
            \n
            'The article discusses several board games that are commonly considered to be poorly designed due to their reliance on luck over strategy, simplistic gameplay, and emphasis on social interaction rather than engaging gameplay. However, some of these games, such as Candy Land and The Game of Life, hold nostalgic value for many players and serve as introductory games for children to learn basic concepts and skills, making them culturally significant despite their perceived shortcomings. Ultimately, opinions on board games are highly subjective and personal experiences can greatly influence how enjoyable or frustrating a game is, leaving the decision of which games to play up to individual gamers.'
            \
            \
            </EXAMPLE>
            ---\
                
                
                
            '''
        },
        {
            'role': 'user',
            'content': f'''In the context of "{query}" , generate an ordered and ranked list from the following text : '''
            + text,
        },

        ]
        )
    
    
    report = response['message']['content']
    
    return report

# %% [markdown]
# ##### Response DataFrame Initialization

# %%
zero_shot_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

# %% [markdown]
# ##### Chosen LLM

# %%
model = "llama3.1:latest"

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ### Zero Shot Prompt

# %%
query =''

# %%
def zero_shot_prompt_MULTI(query):
        zero_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times across all the ARTICLEs to the item that appeared least amount of times across all the ARTICLEs. \
                Each item in the ordered list should have the item name and the item details from the articles. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                Do not include article names in the ordered list.\
                '''
        return zero_shot_prompt

# %%
def zero_shot_prompt_SINGLE(query):
        zero_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times in the user prompt text to the item that appeared least amount of times in the user prompt text. \
                Each item in the ordered list should have the item name and the item details from the user prompt text. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                '''
        return zero_shot_prompt

# %% [markdown]
# ### Few (5) Shot Prompt

# %%
def few5_shot_prompt_SINGLE(query):
        few5_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times in the user prompt text to the item that appeared least amount of times in the user prompt text. \
                Each item in the ordered list should have the item name and the item details from the user prompt text. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the worst mobile phone games released in 2024?" , generate an ordered and ranked list from the following text: The gaming industry has been flooded with new releases every year, but not all of them have received positive reviews or even decent ratings. In this article, we will discuss some of the worst mobile phone games that were released in 2024.  One game that made it to the list is "Mobile Mosaic," a puzzle game that promised a unique experience but turned out to be a clone of existing games with minimal innovation. The game\'s poor graphics and unengaging gameplay left players disappointed, resulting in a rating of only 2 stars on the app store.  Another game that failed to impress was "Echoes of Eternity," an action-adventure game that claimed to have epic battles and quests but turned out to be a repetitive grind fest. Players complained about the game\'s poor controls, long loading times, and lack of challenge, resulting in a rating of only 1.5 stars on the app store.  "Galactic Conquest," a strategy game that promised players the ability to build their own galaxy, turned out to be a shallow experience with no real depth or complexity. Players were frustrated by the game\'s simplistic gameplay and lack of features, leading to a low rating of only 1 star on the app store.  "Dino Dash," an endless runner game that claimed to offer exciting dinosaur-themed gameplay, was met with disappointment from players who found the game\'s graphics and sound effects subpar. The game\'s repetitive gameplay and poor difficulty level also led to it receiving a low rating of only 2 stars on the app store.  "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store.  In conclusion, these games are just some examples of the worst mobile phone games released in 2024. While opinions may vary, one thing is certain - these games failed to deliver on their promises and left players disappointed.
                The gaming industry has seen a significant rise in mobile game development, but not all games have been well-received by players and critics alike. Several mobile games that were released in 2024 have received low ratings and negative reviews due to various reasons such as poor gameplay mechanics, inadequate graphics, and lack of engaging content.  One of the worst mobile phone games released in 2024 is "Boredom Simulator," a game that fails to live up to its title. The game has been criticized for its simplistic and unchallenging gameplay, which does not provide any sense of accomplishment or satisfaction. Additionally, the game\'s graphics are outdated and do not offer anything new or innovative. "Galactic Conquest," a strategy game that promised players the ability to build their own galaxy, turned out to be a shallow experience with no real depth or complexity. Players were frustrated by the game\'s simplistic gameplay and lack of features, leading to a low rating of only 1 star on the app store. Another poorly received mobile game in 2024 is "Epic Fail," a game that attempts to combine elements of popular games but fails to deliver a cohesive experience. The game has been panned for its poor controls, lackluster sound effects, and inadequate storyline.  The mobile game "Laggy\'s Adventure" has also been met with criticism due to its numerous technical issues and glitches. Players have reported experiencing lag, freezing, and crashing, making the gameplay experience frustrating and unenjoyable. "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store. Other notable mentions for worst mobile phone games released in 2024 include "Unnecessary Upgrade," "Cluttered Menu," and "Underwhelming Experience." These games have been panned by players and critics alike due to their poor design, inadequate content, and lack of engagement.
                There is no definitive list as the year has just begun, but there have been some poorly received releases. Games like "Epic Quest," which was criticized for its poor gameplay and numerous bugs, and "Treasure Hunt Masters," which was panned for its aggressive monetization tactics, are examples of games that could be considered among the worst.  Another game that drew criticism is "Real Rumble Boxing," which was accused of being a clone of another popular boxing game. Players also expressed frustration with its lack of original content and poor graphics.  Some games have been criticized for their handling of in-game transactions, such as "Puzzle Legends" and "Treasure Hunt Pro." These games were accused of using aggressive monetization tactics to encourage players to spend more money on in-game purchases.  On the other hand, some games that have received positive reviews are those that offer unique gameplay mechanics or refreshing twists on established genres. For example, "Skybound Odyssey" has been praised for its engaging storyline and addictive gameplay, while "Echoes of Eternity" was commended for its immersive atmosphere and rich graphics.  In terms of what makes a game bad, critics point to poor design choices, such as aggressive monetization tactics or unfair matchmaking. They also mention the importance of regular updates and patches to address issues with the game.  "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store. Overall, the worst mobile phone games released in 2024 are likely to be those that fail to provide engaging gameplay, fair in-game transactions, and regular updates to address player concerns.
                \
                Response: Here is the ranking list for the worst mobile phone games released in 2024 with their summaries from the most to least bad:
                \n
                **#1. Robot Rebellion:**
                'The strategy game "Robot Rebellion" was heavily criticized by players due to its poor optimization, frequent crashes, and bugs, which resulted in a frustrating user experience and ultimately earned it a low rating of only one star on the app store. Additionally, many players felt that the game lacked challenge, further contributing to its overwhelmingly negative reception.'
                \n
                **#2. Galactic Conquest: **
                'The game "Galactic Conquest" was a disappointing strategy game that failed to deliver on its promise, instead offering a shallow experience with simplistic gameplay and limited features, resulting in an extremely low rating of just 1 star from players.'
                \n
                **#3. Echoes of Eternity: **
                'The action-adventure game "Echoes of Eternity" received largely negative reviews from players, who were disappointed by its repetitive gameplay, poor controls, lengthy loading times, and lack of challenge, leading to an overall rating of just 1.5 stars on the app store.'
                \n
                **#4. Mobile Mosaic: **
                "The mobile game Mobile Mosaic was a disappointing experience for players, who were expecting a unique puzzle game but instead found a clone of existing games with minimal innovation. The game's poor graphics and unengaging gameplay led to it being rated just 2 stars in the app store."
                \n
                **#5. Dino Dash: **
                'The game Dino Dash, an endless runner with a dinosaur theme, failed to impress players due to its low-quality graphics and sound effects, leading to a disappointing gaming experience that resulted in a low rating of just 2 stars on the app store.'
                \n
                **#6. Boredom Simulator: **
                'The Boredom Simulator game falls short of meeting its intended promise, featuring simplistic and unchallenging gameplay that fails to deliver a sense of accomplishment or satisfaction, and is also marred by outdated graphics that lack innovation.'
                \n
                **#7. Epic Fail: **
                'The game "Epic Fail" is a disappointing title that tries to blend features from other successful games but ultimately falls short in providing a satisfying gaming experience, with criticism directed towards its subpar controls, mediocre sound effects, and weak storyline.'
                \n
                **#8. Laggy's Adventure: **
                "The video game Laggy's Adventure has received criticism from players due to its numerous technical issues, including lag, freezing, and crashing, which hindered their ability to enjoy the gameplay experience."
                \n
                **#9. Epic Quest: **
                'The game Epic Quest received criticism for its subpar gameplay mechanics and abundance of technical issues, including various bugs that detracted from the overall gaming experience.'
                \n
                **#10. Treasure Hunt Masters: **
                'The game Treasure Hunt Masters is considered to be among the worst due to its aggressive monetization tactics.'
                \n
                **#11. Real Rumble Boxing: **
                'The video game Real Rumble Boxing was criticized for being unoriginal, as it was accused of closely resembling another popular boxing game, and players further expressed dissatisfaction due to its lack of innovative content and subpar graphics.'
                \n
                \n
                'A number of mobile phone games have been panned by both players and critics due to poor design, inadequate content, and lack of engagement, with some games also being criticized for their handling of in-game transactions. These disappointing games are just a few examples of the worst mobile phone games released in 2024, failing to deliver on their promises and leaving players disappointed.'
                \
                \
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the 5 worst board games?" , generate an ordered and ranked list from the following text: Determining the worst board games can be subjective, but several titles have garnered negative reviews and poor ratings over the years. The worst board games often share common characteristics such as complex rules, long playtimes, and a lack of engagement for players.  One game that stands out as particularly poor is "Battleship". Released in 1967 by Milton Bradley (now Hasbro), Battleship has been criticized for its simplistic gameplay and tedious grid-based mechanics. The game relies heavily on luck
                \
                Response: Here is the ranking list for the 3 worst games consoles of all time with their summaries from the most to least bad:
                \n
                **#1. Atari Jaguar:**
                The Atari Jaguar is widely regarded as one of the most disappointing consoles ever made, released in 1993 with high hopes but ultimately failing due to a combination of factors including its high price tag, limited game library, and numerous technical issues. Its catastrophic failure nearly bankrupted the company and led to a significant decline in market value, forcing the console's discontinuation just three years after its release.
                \n
                **#2. Nintendo Virtual Boy:**
                The Nintendo Virtual Boy is widely regarded as one of the worst consoles ever made due to its poor graphics, limited game library, and high price point, which ultimately led to a significant decline in Nintendo's stock value and a reevaluation of their hardware design strategies. Released in 1995 as an attempt at virtual reality gaming, the console failed miserably due to its numerous technical issues, awkward design, and lack of appeal to mainstream gamers, causing Nintendo to abandon the concept of virtual reality gaming for several years.
                \n
                **#3. Sega Dreamcast:**
                The Sega Dreamcast was a console that failed to gain significant market traction, despite its innovative controller design and online capabilities, due to its short lifespan and limited third-party developer support. Despite receiving critical acclaim for its games such as Sonic Adventure and Crazy Taxi, it struggled financially and ultimately declined in sales, leading to its demise.
                \n
                The three consoles described in the text have been widely regarded as among the worst console releases in history due to their poor design, lackluster lineups of games, and limited functionality. Despite some potential benefits from their failures that led to innovations in future gaming technology, these consoles were unable to gain substantial market share or stay afloat for an extended period, ultimately being remembered more for their quirks and flaws than any redeeming qualities.
                \
                \
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the best printer models in 2024?" , generate an ordered and ranked list from the following text input: Choosing the right printer can be overwhelming with so many options available, but here's a comprehensive guide to help you make an informed decision.  **Best Printer Models for Home Users**  1. **HP Envy 5055**: A compact and affordable all-in-one inkjet printer that prints up to 9 ppm in black and white and 7 ppm in color. 2. **Epson Expression Photo HD XP-15000**: A high-end photo printer that offers excellent print quality, Wi-Fi connectivity, and a large 3.7-inch touchscreen display. 3. **Canon PIXMA TS9521C**: A versatile all-in-one printer with wireless printing capabilities, CD/DVD printing, and a compact design.  **Best Printer Models for Office Users**  1. **HP LaserJet Pro M283fdw**: A reliable and high-speed monochrome laser printer that prints up to 30 ppm, has a large paper capacity, and supports mobile printing. 2. **Brother HL-L8360CDW**: A fast and feature-rich color laser printer with Wi-Fi connectivity, NFC, and a touchscreen display. 3. **Xerox VersaLink C405**: A powerful and versatile all-in-one printer that offers advanced security features, wireless connectivity, and a large paper capacity.  **Best Printer Models for Photo Printing**  1. **Epson SureColor P800**: A high-end photo printer with excellent print quality, Wi-Fi connectivity, and a range of paper sizes. 2. **Canon PIXMA PRO-200**: A professional-grade photo printer that offers exceptional print quality, wireless printing capabilities, and a compact design. 3. **HP Envy 7855**: A versatile all-in-one photo printer with wireless printing capabilities, CD/DVD printing, and a large 2.7-inch touchscreen display.  **Best Printer Models for Budget-Friendly Options**  1. **Canon PIXMA TS202**: A budget-friendly all-in-one inkjet printer that prints up to 8 ppm in black and white and 4 ppm in color. 2. **Epson Expression Home XP-4100**: A compact and affordable all-in-one inkjet printer with wireless printing capabilities and a large 2.7-inch touchscreen display. 3. **HP DeskJet Ink Advantage 2135**: A budget-friendly all-in-one inkjet printer that prints up to 7 ppm in black and white and 4 ppm in color.  **Key Features to Consider**  1. **Print Resolution**: Look for printers with high print resolutions (at least 4800 x 1200 dpi) for excellent photo printing quality. 2. **Wireless Connectivity**: Choose a printer with Wi-Fi or Bluetooth connectivity for convenient wireless printing from mobile devices. 3. **Paper Capacity**: Select a printer with a large paper capacity to minimize refills and reduce waste. 4. **Ink Costs**: Consider the cost of replacement ink cartridges when choosing a printer, as some models may be more expensive than others. 5. **Noise Level**: Opt for a printer with low noise levels (less than 40 dB) if you plan to use it in a quiet environment.  By considering these key features and best printer models, you'll be able to make an informed decision when choosing the right printer for your needs in 2024.
                This question is a common query among individuals and businesses looking for reliable and high-quality printers that can meet their printing needs.  According to recent reviews and ratings, some of the top-rated printer models in 2024 include the HP OfficeJet Pro 9015, Epson Expression ET-2750 EcoTank, Canon imageCLASS LBP612Cdw, Brother MFC-J6930DW, Epson Expression Photo HD XP-15000: A high-end photo printer that offers excellent print quality, Wi-Fi connectivity, and a large 3.7-inch touchscreen display and Xerox VersaLink C405.  The HP OfficeJet Pro 9015 is a compact and feature-rich all-in-one printer that offers high-quality printing, scanning, and copying capabilities at an affordable price. It also features wireless connectivity, allowing users to print from their mobile devices.  On the other hand, the Epson Expression ET-2750 EcoTank is a budget-friendly option that offers superior ink tank capacity and ultra-low cost per page printing. This printer also comes with Wi-Fi connectivity and USB connectivity options for flexible use.  The Canon imageCLASS LBP612Cdw is a compact all-in-one laser printer that provides fast and reliable printing, scanning, and copying capabilities. It also features wireless connectivity and mobile printing capabilities.  Meanwhile, the Brother MFC-J6930DW is a versatile inkjet printer that offers high-quality printing, scanning, and copying capabilities at an affordable price. This printer comes with dual paper trays, allowing users to print on various media sizes without interruption. HP Envy 5055: A compact and affordable all-in-one inkjet printer that prints up to 9 ppm in black and white and 7 ppm in color. Lastly, the Xerox VersaLink C405 is a professional-grade laser printer designed for heavy-duty use in small businesses or workgroups. It features wireless connectivity, mobile printing, and cloud-based printing capabilities.  These top-rated printer models are available in various price ranges and come with different features and specifications to cater to diverse user needs. When choosing the best printer model in 2024, it is essential to consider factors such as print quality, speed, ink or toner cost, connectivity options, and compatibility with various devices.
                This question can be answered by considering several factors such as budget, intended use, and features required. For home users, some top picks for printers include the HP Envy Pro 6455, Canon PIXMA TS6320, and Epson EcoTank ET-3750.  These printers offer a range of features including wireless connectivity, high-quality printing, and cost-effective ink options. The HP Envy Pro 6455 is an all-in-one printer that can print, scan, and copy documents with ease, making it suitable for home offices or small businesses.  The Canon PIXMA TS6320 offers excellent color accuracy and is ideal for those who want to print high-quality photos. It also has a compact design and wireless connectivity options. On the other hand, the Epson EcoTank ET-3750 is a great option for those on a budget as it comes with refillable ink tanks that can save users up to 90% of their printing costs.  For small businesses or professionals who need high-volume printing capabilities, some top picks include the HP LaserJet Pro M255dw, Brother HL-L2395DW, and Canon imageCLASS LBP612Cdw. These printers offer fast print speeds, high-quality text output, and wireless connectivity options to meet the demands of busy offices.  The HP LaserJet Pro M255dw is a monochrome laser printer that offers fast print speeds and wireless connectivity options. The Brother HL-L2395DW is another reliable option for small businesses or professionals who need high-volume printing capabilities. It comes with wireless connectivity options, automatic two-sided printing, and a compact design.  For photographers and graphic designers who require high-quality photo printing, some top picks include the Epson Expression Photo HD XP-15000, Canon PIXMA PRO-200, and HP DesignJet T830. These printers offer excellent color accuracy, high-quality photo printing capabilities, and wireless connectivity options to meet the demands of professionals.  The Epson Expression Photo HD XP-15000 is a great option for those who want to print high-quality photos with ease. It comes with refillable ink tanks that can save users up to 80% of their printing costs. Epson Expression Photo HD XP-15000: A high-end photo printer that offers excellent print quality, Wi-Fi connectivity, and a large 3.7-inch touchscreen display. The Canon PIXMA PRO-200 offers excellent color accuracy and is ideal for professional photographers or graphic designers.  In conclusion, the best printer models in 2024 depend on individual needs and requirements. Home users may prefer all-in-one printers like the HP Envy Pro 6455 or Epson EcoTank ET-3750, while small businesses or professionals may require high-volume printing capabilities from printers like the HP LaserJet Pro M255dw or Canon imageCLASS LBP612Cdw.  Photographers and graphic designers who require high-quality photo printing may prefer printers like the Epson Expression Photo HD XP-15000 or Canon PIXMA PRO-200. Xerox VersaLink C405 is a professional-grade laser printer designed for heavy-duty use in small businesses or workgroups. It features wireless connectivity, mobile printing, and cloud-based printing capabilities. Ultimately, choosing the best printer model depends on individual needs, budget, and intended use, making it essential to research and compare different options before making a final decision.  When selecting a printer in 2024, consider factors such as print quality, speed, connectivity options, and cost-effectiveness. Researching online reviews, comparing prices, and considering warranty and customer support can also help individuals make an informed decision when choosing the best printer model for their needs.  Furthermore, with advancements in technology, some printers now offer smart features like voice control, mobile printing capabilities, and automatic document feeders to streamline workflow and save time. Considering these factors will enable users to find a reliable and efficient printer that meets their specific requirements.  Lastly, it is worth noting that some manufacturers offer subscription-based services or cloud-connected features that can enhance the user experience and provide access to advanced features and benefits. These subscriptions may include ink replacement plans, automatic software updates, or enhanced security features, which can further optimize printing performance and convenience.  In summary, selecting the best printer model in 2024 requires careful consideration of individual needs, budget, and intended use. By researching different options, comparing prices, and considering factors such as print quality, speed, connectivity options, and cost-effectiveness, individuals can find a reliable and efficient printer that meets their specific requirements.  Additionally, exploring smart features, subscription-based services, and cloud-connected capabilities can further enhance the user experience and provide access to advanced features and benefits. With so many options available in 2024, there is sure to be a printer model that suits every need and budget, making it essential to do thorough research before making a final decision.  Overall, choosing the best printer model in 2024 requires considering various factors such as budget, intended use, print quality, speed, connectivity options, cost-effectiveness, and additional features like smart capabilities or subscription-based services.
                \
                Response: Here is the ranking list for the best printer models in 2024 with their summaries from most to least:
                \n
                **#1. Epson Expression Photo HD XP-15000:**
                \n
                **#16. Brother MFC-J6930DW:**
                'The Brother MFC-J6930DW is a multifunctional inkjet printer that provides high-quality printing, scanning, and copying abilities at an affordable cost, also featuring dual paper trays for uninterrupted printing on various media sizes.'
                \n
                **#17. HP Envy Pro 6455:**
                'The HP Envy Pro 6455 is a versatile all-in-one printer designed to meet the needs of home offices or small businesses, offering printing, scanning, and copying capabilities.'
                \n
                **#18. Canon PIXMA TS6320:**
                'The Canon PIXMA TS6320 offers excellent color accuracy, making it suitable for printing high-quality photos, while its compact design and wireless connectivity features provide added convenience.'
                \n
                **#19. Epson EcoTank ET-3750:**
                'The Epson EcoTank ET-3750 is a cost-effective printer option, offering significant savings by using refillable ink tanks, which can reduce printing costs by up to 90%.'
                \n
                **#20. HP LaserJet Pro M255dw:**
                'The HP LaserJet Pro M255dw is a monochrome laser printer that provides quick print capabilities and allows for wireless connection options, making it convenient to use in various settings.'
                \n
                **#21. Brother HL-L2395DW:**
                'The Brother HL-L2395DW is a reliable printer option that is well-suited for small businesses or professionals who require high-volume printing capabilities, offering features such as wireless connectivity, automatic two-sided printing, and a compact design.'
                \n
                \n
                'When selecting the best printer for your needs in 2024, it is essential to consider several key features and factors. These include high print resolutions (at least 4800 x 1200 dpi) for excellent photo printing quality, wireless connectivity options such as Wi-Fi or Bluetooth, a large paper capacity to minimize refills and waste, affordable ink costs, and low noise levels for quiet environments. Additionally, individuals should research different models, compare prices, and consider factors such as print quality, speed, connectivity options, cost-effectiveness, and smart features like voice control and mobile printing capabilities. Furthermore, subscription-based services or cloud-connected features can provide access to advanced features and benefits, making it possible to find a reliable and efficient printer that meets specific requirements. By carefully considering individual needs, budget, and intended use, as well as exploring various options and features, individuals can make an informed decision when choosing the best printer model for 2024.'
                \
                ---\
                '''
        return few5_shot_prompt

# %%
def few5_shot_prompt_MULTI(query):
        few5_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times across all the ARTICLEs to the item that appeared least amount of times across all the ARTICLEs. \
                Each item in the ordered list should have the item name and the item details from the articles. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                Do not include article names in the ordered list.\
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the worst mobile phone games released in 2024?" , generate an ordered and ranked list from the following ARTICLEs: Article #1:
                The gaming industry has been flooded with new releases every year, but not all of them have received positive reviews or even decent ratings. In this article, we will discuss some of the worst mobile phone games that were released in 2024.  One game that made it to the list is "Mobile Mosaic," a puzzle game that promised a unique experience but turned out to be a clone of existing games with minimal innovation. The game\'s poor graphics and unengaging gameplay left players disappointed, resulting in a rating of only 2 stars on the app store.  Another game that failed to impress was "Echoes of Eternity," an action-adventure game that claimed to have epic battles and quests but turned out to be a repetitive grind fest. Players complained about the game\'s poor controls, long loading times, and lack of challenge, resulting in a rating of only 1.5 stars on the app store.  "Galactic Conquest," a strategy game that promised players the ability to build their own galaxy, turned out to be a shallow experience with no real depth or complexity. Players were frustrated by the game\'s simplistic gameplay and lack of features, leading to a low rating of only 1 star on the app store.  "Dino Dash," an endless runner game that claimed to offer exciting dinosaur-themed gameplay, was met with disappointment from players who found the game\'s graphics and sound effects subpar. The game\'s repetitive gameplay and poor difficulty level also led to it receiving a low rating of only 2 stars on the app store.  "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store.  In conclusion, these games are just some examples of the worst mobile phone games released in 2024. While opinions may vary, one thing is certain - these games failed to deliver on their promises and left players disappointed.
                Article #2:
                The gaming industry has seen a significant rise in mobile game development, but not all games have been well-received by players and critics alike. Several mobile games that were released in 2024 have received low ratings and negative reviews due to various reasons such as poor gameplay mechanics, inadequate graphics, and lack of engaging content.  One of the worst mobile phone games released in 2024 is "Boredom Simulator," a game that fails to live up to its title. The game has been criticized for its simplistic and unchallenging gameplay, which does not provide any sense of accomplishment or satisfaction. Additionally, the game\'s graphics are outdated and do not offer anything new or innovative. "Galactic Conquest," a strategy game that promised players the ability to build their own galaxy, turned out to be a shallow experience with no real depth or complexity. Players were frustrated by the game\'s simplistic gameplay and lack of features, leading to a low rating of only 1 star on the app store. Another poorly received mobile game in 2024 is "Epic Fail," a game that attempts to combine elements of popular games but fails to deliver a cohesive experience. The game has been panned for its poor controls, lackluster sound effects, and inadequate storyline.  The mobile game "Laggy\'s Adventure" has also been met with criticism due to its numerous technical issues and glitches. Players have reported experiencing lag, freezing, and crashing, making the gameplay experience frustrating and unenjoyable. "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store. Other notable mentions for worst mobile phone games released in 2024 include "Unnecessary Upgrade," "Cluttered Menu," and "Underwhelming Experience." These games have been panned by players and critics alike due to their poor design, inadequate content, and lack of engagement.
                Article #3:
                There is no definitive list as the year has just begun, but there have been some poorly received releases. Games like "Epic Quest," which was criticized for its poor gameplay and numerous bugs, and "Treasure Hunt Masters," which was panned for its aggressive monetization tactics, are examples of games that could be considered among the worst.  Another game that drew criticism is "Real Rumble Boxing," which was accused of being a clone of another popular boxing game. Players also expressed frustration with its lack of original content and poor graphics.  Some games have been criticized for their handling of in-game transactions, such as "Puzzle Legends" and "Treasure Hunt Pro." These games were accused of using aggressive monetization tactics to encourage players to spend more money on in-game purchases.  On the other hand, some games that have received positive reviews are those that offer unique gameplay mechanics or refreshing twists on established genres. For example, "Skybound Odyssey" has been praised for its engaging storyline and addictive gameplay, while "Echoes of Eternity" was commended for its immersive atmosphere and rich graphics.  In terms of what makes a game bad, critics point to poor design choices, such as aggressive monetization tactics or unfair matchmaking. They also mention the importance of regular updates and patches to address issues with the game.  "Robot Rebellion," a strategy game that promised players the ability to build their own robot armies, turned out to be a poorly optimized game with frequent crashes and bugs. Players were frustrated by the game\'s lack of challenge and poor user experience, resulting in a low rating of only 1 star on the app store. Overall, the worst mobile phone games released in 2024 are likely to be those that fail to provide engaging gameplay, fair in-game transactions, and regular updates to address player concerns.
                \
                Response: Here is the ranking list for the worst mobile phone games released in 2024 with their summaries from the most to least bad:
                \n
                **#1. Robot Rebellion:**
                'The strategy game "Robot Rebellion" was heavily criticized by players due to its poor optimization, frequent crashes, and bugs, which resulted in a frustrating user experience and ultimately earned it a low rating of only one star on the app store. Additionally, many players felt that the game lacked challenge, further contributing to its overwhelmingly negative reception.'
                \n
                **#2. Galactic Conquest: **
                'The game "Galactic Conquest" was a disappointing strategy game that failed to deliver on its promise, instead offering a shallow experience with simplistic gameplay and limited features, resulting in an extremely low rating of just 1 star from players.'
                \n
                **#3. Echoes of Eternity: **
                'The action-adventure game "Echoes of Eternity" received largely negative reviews from players, who were disappointed by its repetitive gameplay, poor controls, lengthy loading times, and lack of challenge, leading to an overall rating of just 1.5 stars on the app store.'
                \n
                **#4. Mobile Mosaic: **
                "The mobile game Mobile Mosaic was a disappointing experience for players, who were expecting a unique puzzle game but instead found a clone of existing games with minimal innovation. The game's poor graphics and unengaging gameplay led to it being rated just 2 stars in the app store."
                \n
                **#5. Dino Dash: **
                'The game Dino Dash, an endless runner with a dinosaur theme, failed to impress players due to its low-quality graphics and sound effects, leading to a disappointing gaming experience that resulted in a low rating of just 2 stars on the app store.'
                \n
                **#6. Boredom Simulator: **
                'The Boredom Simulator game falls short of meeting its intended promise, featuring simplistic and unchallenging gameplay that fails to deliver a sense of accomplishment or satisfaction, and is also marred by outdated graphics that lack innovation.'
                \n
                **#7. Epic Fail: **
                'The game "Epic Fail" is a disappointing title that tries to blend features from other successful games but ultimately falls short in providing a satisfying gaming experience, with criticism directed towards its subpar controls, mediocre sound effects, and weak storyline.'
                \n
                **#8. Laggy's Adventure: **
                "The video game Laggy's Adventure has received criticism from players due to its numerous technical issues, including lag, freezing, and crashing, which hindered their ability to enjoy the gameplay experience."
                \n
                **#9. Epic Quest: **
                'The game Epic Quest received criticism for its subpar gameplay mechanics and abundance of technical issues, including various bugs that detracted from the overall gaming experience.'
                \n
                **#10. Treasure Hunt Masters: **
                'The game Treasure Hunt Masters is considered to be among the worst due to its aggressive monetization tactics.'
                \n
                **#11. Real Rumble Boxing: **
                'The video game Real Rumble Boxing was criticized for being unoriginal, as it was accused of closely resembling another popular boxing game, and players further expressed dissatisfaction due to its lack of innovative content and subpar graphics.'
                \n
                \n
                'A number of mobile phone games have been panned by both players and critics due to poor design, inadequate content, and lack of engagement, with some games also being criticized for their handling of in-game transactions. These disappointing games are just a few examples of the worst mobile phone games released in 2024, failing to deliver on their promises and leaving players disappointed.'
                \
                \
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the 5 worst board games?" , generate an ordered and ranked list from the following ARTICLEs: Article #1:
1. **Epson SureColor P800**: A high-end photo printer with excellent print quality, Wi-Fi connectivity, and a range of paper sizes. 2. **Canon PIXMA PRO-200**: A professional-grade photo printer that offers exceptional print quality, wireless printing capabilities, and a compact design. 3. **HP Envy 7855**: A versatile all-in-one photo printer with wireless printing capabilities, CD/DVD printing, and a large 2.7-inch touchscreen display.  **Best Printer Models for Budget-Friendly Options**  1. **Canon PIXMA TS202**: A budget-friendly all-in-one inkjet printer that prints up to 8 ppm in black and white and 4 ppm in color. 2. **Epson Expression Home XP-4100**: A compact and affordable all-in-one inkjet printer with wireless printing capabilities and a large 2.7-inch touchscreen display. 3. **HP DeskJet Ink Advantage 2135**: A budget-friendly all-in-one inkjet printer that prints up to 7 ppm in black and white and 4 ppm in color.  **Key Features to Consider**  1. **Print Resolution**: Look for printers with high print resolutions (at least 4800 x 1200 dpi) for excellent photo printing quality. 2. **Wireless Connectivity**: Choose a printer with Wi-Fi or Bluetooth connectivity for convenient wireless printing from mobile devices. 3. **Paper Capacity**: Select a printer with a large paper capacity to minimize refills and reduce waste. 4. **Ink Costs**: Consider the cost of replacement ink cartridges when choosing a printer, as some models may be more expensive than others. 5. **Noise Level**: Opt for a printer with low noise levels (less than 40 dB) if you plan to use it in a quiet environment.  By considering these key features and best printer models, you'll be able to make an informed decision when choosing the right printer for your needs in 2024.
                Article #2:
                This question is a common query among individuals and businesses looking for reliable and high-quality printers that can meet their printing needs.  According to recent reviews and ratings, some of the top-rated printer models in 2024 include the HP OfficeJet Pro 9015, Epson Expression ET-2750 EcoTank, Canon imageCLASS LBP612Cdw, Brother MFC-J6930DW, Epson Expression Photo HD XP-15000: A high-end photo printer that offers excellent print quality, Wi-Fi connectivity, and a large 3.7-inch touchscreen display and Xerox VersaLink C405.  The HP OfficeJet Pro 9015 is a compact and feature-rich all-in-one printer that offers high-quality printing, scanning, and copying capabilities at an affordable price. It also features wireless connectivity, allowing users to print from their mobile devices.  On the other hand, the Epson Expression ET-2750 EcoTank is a budget-friendly option that offers superior ink tank capacity and ultra-low cost per page printing. This printer also comes with Wi-Fi connectivity and USB connectivity options for flexible use.  The Canon imageCLASS LBP612Cdw is a compact all-in-one laser printer that provides fast and reliable printing, scanning, and copying capabilities. It also features wireless connectivity and mobile printing capabilities.  Meanwhile, the Brother MFC-J6930DW is a versatile inkjet printer that offers high-quality printing, scanning, and copying capabilities at an affordable price. This printer comes with dual paper trays, allowing users to print on various media sizes without interruption. HP Envy 5055: A compact and affordable all-in-one inkjet printer that prints up to 9 ppm in black and white and 7 ppm in color. Lastly, the Xerox VersaLink C405 is a professional-grade laser printer designed for heavy-duty use in small businesses or workgroups. It features wireless connectivity, mobile printing, and cloud-based printing capabilities.  These top-rated printer models are available in various price ranges and come with different features and specifications to cater to diverse user needs. When choosing the best printer model in 2024, it is essential to consider factors such as print quality, speed, ink or toner cost, connectivity options, and compatibility with various devices.
                Article #3:
                This question can be answered by considering several factors such as budget, intended use, and features required. For home users, some top picks for printers include the HP Envy Pro 6455, Canon PIXMA TS6320, and Epson EcoTank ET-3750.  These printers offer a range of features including wireless connectivity, high-quality printing, and cost-effective ink options. The HP Envy Pro 6455 is an all-in-one printer that can print, scan, and copy documents with ease, making it suitable for home offices or small businesses.  The Canon PIXMA TS6320 offers excellent color accuracy and is ideal for those who want to print high-quality photos. It also has a compact design and wireless connectivity options. On the other hand, the Epson EcoTank ET-3750 is a great option for those on a budget as it comes with refillable ink tanks that can save users up to 90% of their printing costs.  For small businesses or professionals who need high-volume printing capabilities, some top picks include the HP LaserJet Pro M255dw, Brother HL-L2395DW, and Canon imageCLASS LBP612Cdw. These printers offer fast print speeds, high-quality text output, and wireless connectivity options to meet the demands of busy offices.  The HP LaserJet Pro M255dw is a monochrome laser printer that offers fast print speeds and wireless connectivity options. The Brother HL-L2395DW is another reliable option for small businesses or professionals who need high-volume printing capabilities. It comes with wireless connectivity options, automatic two-sided printing, and a compact design.  For photographers and graphic designers who require high-quality photo printing, some top picks include the Epson Expression Photo HD XP-15000, Canon PIXMA PRO-200, and HP DesignJet T830. These printers offer excellent color accuracy, high-quality photo printing capabilities, and wireless connectivity options to meet the demands of professionals.  The Epson Expression Photo HD XP-15000 is a great option for those who want to print high-quality photos with ease. It comes with refillable ink tanks that can save users up to 80% of their printing costs. Epson Expression Photo HD XP-15000: A high-end photo printer that offers excellent print quality, Wi-Fi connectivity, and a large 3.7-inch touchscreen display. The Canon PIXMA PRO-200 offers excellent color accuracy and is ideal for professional photographers or graphic designers.  In conclusion, the best printer models in 2024 depend on individual needs and requirements. Home users may prefer all-in-one printers like the HP Envy Pro 6455 or Epson EcoTank ET-3750, while small businesses or professionals may require high-volume printing capabilities from printers like the HP LaserJet Pro M255dw or Canon imageCLASS LBP612Cdw.  Photographers and graphic designers who require high-quality photo printing may prefer printers like the Epson Expression Photo HD XP-15000 or Canon PIXMA PRO-200. Xerox VersaLink C405 is a professional-grade laser printer designed for heavy-duty use in small businesses or workgroups. It features wireless connectivity, mobile printing, and cloud-based printing capabilities. Ultimately, choosing the best printer model depends on individual needs, budget, and intended use, making it essential to research and compare different options before making a final decision.  When selecting a printer in 2024, consider factors such as print quality, speed, connectivity options, and cost-effectiveness. Researching online reviews, comparing prices, and considering warranty and customer support can also help individuals make an informed decision when choosing the best printer model for their needs.  Furthermore, with advancements in technology, some printers now offer smart features like voice control, mobile printing capabilities, and automatic document feeders to streamline workflow and save time. Considering these factors will enable users to find a reliable and efficient printer that meets their specific requirements.  Lastly, it is worth noting that some manufacturers offer subscription-based services or cloud-connected features that can enhance the user experience and provide access to advanced features and benefits. These subscriptions may include ink replacement plans, automatic software updates, or enhanced security features, which can further optimize printing performance and convenience.  In summary, selecting the best printer model in 2024 requires careful consideration of individual needs, budget, and intended use. By researching different options, comparing prices, and considering factors such as print quality, speed, connectivity options, and cost-effectiveness, individuals can find a reliable and efficient printer that meets their specific requirements.  Additionally, exploring smart features, subscription-based services, and cloud-connected capabilities can further enhance the user experience and provide access to advanced features and benefits. With so many options available in 2024, there is sure to be a printer model that suits every need and budget, making it essential to do thorough research before making a final decision.  Overall, choosing the best printer model in 2024 requires considering various factors such as budget, intended use, print quality, speed, connectivity options, cost-effectiveness, and additional features like smart capabilities or subscription-based services.
                **#14. Epson Expression ET-2750 EcoTank:**
                'The Epson Expression ET-2750 EcoTank is a budget-friendly printer that provides superior ink tank capacity, allowing users to print at an extremely low cost per page, while also offering convenient connectivity options including Wi-Fi and USB.'
                \n
                **#15. Canon imageCLASS LBP612Cdw:**
                'The Canon imageCLASS LBP612Cdw is a compact all-in-one laser printer that offers fast and reliable performance, including printing, scanning, and copying functions, as well as wireless connectivity and mobile printing capabilities.'
                \n
                **#16. Brother MFC-J6930DW:**
                'The Brother MFC-J6930DW is a multifunctional inkjet printer that provides high-quality printing, scanning, and copying abilities at an affordable cost, also featuring dual paper trays for uninterrupted printing on various media sizes.'
                \n
                **#17. HP Envy Pro 6455:**
                'The HP Envy Pro 6455 is a versatile all-in-one printer designed to meet the needs of home offices or small businesses, offering printing, scanning, and copying capabilities.'
                \n
                **#18. Canon PIXMA TS6320:**
                'The Canon PIXMA TS6320 offers excellent color accuracy, making it suitable for printing high-quality photos, while its compact design and wireless connectivity features provide added convenience.'
                \n
                **#19. Epson EcoTank ET-3750:**
                'The Epson EcoTank ET-3750 is a cost-effective printer option, offering significant savings by using refillable ink tanks, which can reduce printing costs by up to 90%.'
                \n
                **#20. HP LaserJet Pro M255dw:**
                'The HP LaserJet Pro M255dw is a monochrome laser printer that provides quick print capabilities and allows for wireless connection options, making it convenient to use in various settings.'
                \n
                **#21. Brother HL-L2395DW:**
                'The Brother HL-L2395DW is a reliable printer option that is well-suited for small businesses or professionals who require high-volume printing capabilities, offering features such as wireless connectivity, automatic two-sided printing, and a compact design.'
                \n
                \n
                'When selecting the best printer for your needs in 2024, it is essential to consider several key features and factors. These include high print resolutions (at least 4800 x 1200 dpi) for excellent photo printing quality, wireless connectivity options such as Wi-Fi or Bluetooth, a large paper capacity to minimize refills and waste, affordable ink costs, and low noise levels for quiet environments. Additionally, individuals should research different models, compare prices, and consider factors such as print quality, speed, connectivity options, cost-effectiveness, and smart features like voice control and mobile printing capabilities. Furthermore, subscription-based services or cloud-connected features can provide access to advanced features and benefits, making it possible to find a reliable and efficient printer that meets specific requirements. By carefully considering individual needs, budget, and intended use, as well as exploring various options and features, individuals can make an informed decision when choosing the best printer model for 2024.'
                \
                ---\
                '''
        return few5_shot_prompt

# %% [markdown]
# #### One Shot Prompt

# %%
def one_shot_prompt_SINGLE(query):
        one_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times in the user prompt text to the item that appeared least amount of times in the user prompt text. \
                Each item in the ordered list should have the item name and the item details from the user prompt text. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                ---\
                <EXAMPLE>\
                \n
                **#2. The Matrix: **
                'The Matrix (1999), directed by the Wachowskis, is an iconic and influential sci-fi movie that revolutionized visual effects with its "bullet time" sequences and "green screen" work. The film tells the story of Neo, a computer hacker who discovers his life has been simulated within a virtual reality program created by intelligent machines to subdue humanity, forcing him to choose between loyalty to humans and connection with the machines. With its innovative special effects, intricate storyline, and thought-provoking themes, The Matrix is widely regarded as one of the greatest sci-fi films ever made, redefining the genre with its groundbreaking storytelling and visuals.'
                \n
                **#3. 2001: A Space Odyssey: **
                "Stanley Kubrick's 2001: A Space Odyssey (1968) is widely regarded as one of the greatest films of all time and has had a profound influence on popular culture, particularly in the science fiction genre. The film follows a team of astronauts on a mission to Jupiter who encounter a mysterious alien monolith that holds the key to humanity's evolution and destiny, prompting them to confront their own existence and the possibility of extraterrestrial life. With its groundbreaking special effects, philosophical themes, and enigmatic ending, 2001: A Space Odyssey continues to inspire new generations of filmmakers and sci-fi enthusiasts with its thought-provoking exploration of human evolution, technology, and existentialism."
                \n
                **#4. Alien: **
                'The iconic sci-fi horror film Alien, directed by Ridley Scott in 1979, tells the story of a crew of space explorers being stalked and killed one by one by a deadly alien creature on a distant planet. With its groundbreaking visual effects, memorable characters, and claustrophobic tension, Alien has become a seminal work of science fiction that revolutionized the horror genre with its terrifying alien creatures and eerie setting.'
                \n
                **#5. The Last Jedi: **
                "The Last Jedi, directed by Rian Johnson, is often considered one of the greatest sci-fi movies of all time due to its bold storytelling, memorable characters, and subversive themes. The film follows Rey's journey as she searches for Luke Skywalker, who has gone into hiding after his failure to stop Kylo Ren from destroying the Resistance's fleet, while also grappling with her own destiny and the mysteries of the Force."
                \n
                \n
                'The five sci-fi movies discussed are widely regarded as some of the greatest films ever made due to their thought-provoking themes, visually stunning depiction of a futuristic world, and profound impact on popular culture. These movies have captivated audiences with their imaginative storylines, memorable characters, and groundbreaking special effects, solidifying their places in the pantheon of science fiction cinema and continuing to be widely discussed and debated by fans of science fiction. Their complex world-building, exploration of deeper themes, and enduring influence on the genre have cemented their status as essential viewing for fans of science fiction and anyone interested in exploring new ideas and perspectives.'
                \
                ---\
                '''
        return one_shot_prompt

# %%
def one_shot_prompt_MULTI(query):
        one_shot_prompt =  f'''You are a reviewer generating an ordered and numbered ranked list based on {query} only. \
                Each item in the ordered list should be ordered from item that appeared most amount of times across all the ARTICLEs to the item that appeared least amount of times across all the ARTICLEs. \
                Each item in the ordered list should have the item name and the item details from the articles. \
                Bold each item on the ranking list in the response.\
                To make text bold, enclose it with double asterisks (**). Example: **text** becomes bold.\
                Do not include article names in the ordered list.\
                ---\
                <EXAMPLE>\
                Prompt: In the context of "What are the top 5 best sci-fi movies of all time?" , generate an ordered and ranked list from the following ARTICLEs: Article #1: 
                'Blade Runner, directed by Ridley Scott in 1982, is a groundbreaking and thought-provoking sci-fi classic that explores complex themes about humanity, identity, and what it means to be alive. Set in a dystopian future where synthetic beings known as replicants are hunted by special police officers called blade runners, the film delves into questions about artificial intelligence, empathy, and humanity through its atmospheric visuals, rich themes, and memorable characters, ultimately becoming a cult classic among sci-fi fans that has influenced numerous other movies and TV shows.'
                \n
                **#2. The Matrix: **
                'The Matrix (1999), directed by the Wachowskis, is an iconic and influential sci-fi movie that revolutionized visual effects with its "bullet time" sequences and "green screen" work. The film tells the story of Neo, a computer hacker who discovers his life has been simulated within a virtual reality program created by intelligent machines to subdue humanity, forcing him to choose between loyalty to humans and connection with the machines. With its innovative special effects, intricate storyline, and thought-provoking themes, The Matrix is widely regarded as one of the greatest sci-fi films ever made, redefining the genre with its groundbreaking storytelling and visuals.'
                \n
                **#3. 2001: A Space Odyssey: **
                "Stanley Kubrick's 2001: A Space Odyssey (1968) is widely regarded as one of the greatest films of all time and has had a profound influence on popular culture, particularly in the science fiction genre. The film follows a team of astronauts on a mission to Jupiter who encounter a mysterious alien monolith that holds the key to humanity's evolution and destiny, prompting them to confront their own existence and the possibility of extraterrestrial life. With its groundbreaking special effects, philosophical themes, and enigmatic ending, 2001: A Space Odyssey continues to inspire new generations of filmmakers and sci-fi enthusiasts with its thought-provoking exploration of human evolution, technology, and existentialism."
                \n
                **#4. Alien: **
                'The iconic sci-fi horror film Alien, directed by Ridley Scott in 1979, tells the story of a crew of space explorers being stalked and killed one by one by a deadly alien creature on a distant planet. With its groundbreaking visual effects, memorable characters, and claustrophobic tension, Alien has become a seminal work of science fiction that revolutionized the horror genre with its terrifying alien creatures and eerie setting.'
                \n
                **#5. The Last Jedi: **
                "The Last Jedi, directed by Rian Johnson, is often considered one of the greatest sci-fi movies of all time due to its bold storytelling, memorable characters, and subversive themes. The film follows Rey's journey as she searches for Luke Skywalker, who has gone into hiding after his failure to stop Kylo Ren from destroying the Resistance's fleet, while also grappling with her own destiny and the mysteries of the Force."
                \n
                \n
                'The five sci-fi movies discussed are widely regarded as some of the greatest films ever made due to their thought-provoking themes, visually stunning depiction of a futuristic world, and profound impact on popular culture. These movies have captivated audiences with their imaginative storylines, memorable characters, and groundbreaking special effects, solidifying their places in the pantheon of science fiction cinema and continuing to be widely discussed and debated by fans of science fiction. Their complex world-building, exploration of deeper themes, and enduring influence on the genre have cemented their status as essential viewing for fans of science fiction and anyone interested in exploring new ideas and perspectives.'
                \
                ---\
                '''
        return one_shot_prompt

# %% [markdown]
# #### Testing

# %% [markdown]
# ### Response Generation for Zero Shot prompting with SLT input

# %%
zero_shot_multi_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_Multiple_Generated_Summaries
    query = row.Query
    prompt = zero_shot_prompt_MULTI(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = MULTI_generate_report_with_query(text, model,query,prompt)
    response_text_2 = MULTI_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_shot_multi_response_df.loc[-1] = ref_row
    zero_shot_multi_response_df.index = zero_shot_multi_response_df.index + 1  #shift index
    zero_shot_multi_response_df = zero_shot_multi_response_df.sort_index()  #sort by index

# %%
zero_shot_multi_response_df.to_csv('FinalTest_zero_shot_multi_response_df.csv')

# %% [markdown]
# ### Response Generation for Zero Shot COT with Process Logic in User role prompting with SCT input

# %%
zero_shot_COT_USER_single_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_1_Generated_Summary
    query = row.Query
    prompt = zero_shot_prompt_SINGLE(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = ZERO_STEP_USER_COT_SINGLE_generate_report_with_query(text, model,query,prompt)
    response_text_2 = ZERO_STEP_USER_COT_SINGLE_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_shot_COT_USER_single_response_df.loc[-1] = ref_row
    zero_shot_COT_USER_single_response_df.index = zero_shot_COT_USER_single_response_df.index + 1  #shift index
    zero_shot_COT_USER_single_response_df = zero_shot_COT_USER_single_response_df.sort_index()  #sort by index

# %%
zero_shot_COT_USER_single_response_df.to_csv('zero_shot_COT_USER_single_response_df.csv')

# %% [markdown]
# ### Response Generation for Zero Shot COT with Process Logic in System role prompting with SCT input

# %%
zero_shot_COT_SYS_single_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_1_Generated_Summary
    query = row.Query
    prompt = zero_shot_prompt_SINGLE(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = ZERO_STEP_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt)
    response_text_2 = ZERO_STEP_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_shot_COT_SYS_single_response_df.loc[-1] = ref_row
    zero_shot_COT_SYS_single_response_df.index = zero_shot_COT_SYS_single_response_df.index + 1  #shift index
    zero_shot_COT_SYS_single_response_df = zero_shot_COT_SYS_single_response_df.sort_index()  #sort by index

# %%
zero_shot_COT_SYS_single_response_df.to_csv('zero_shot_COT_SYS_single_response_df.csv')

# %% [markdown]
# ### Response Generation for Zero Shot COT with Process Logic in Assistant role prompting with SCT input

# %%
zero_shot_COT_ASST_single_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_1_Generated_Summary
    query = row.Query
    prompt = zero_shot_prompt_SINGLE(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = ZERO_STEP_ASST_COT_SINGLE_generate_report_with_query(text, model,query,prompt)
    response_text_2 = ZERO_STEP_ASST_COT_SINGLE_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_shot_COT_ASST_single_response_df.loc[-1] = ref_row
    zero_shot_COT_ASST_single_response_df.index = zero_shot_COT_ASST_single_response_df.index + 1  #shift index
    zero_shot_COT_ASST_single_response_df = zero_shot_COT_ASST_single_response_df.sort_index()  #sort by index

# %%
zero_shot_COT_ASST_single_response_df.to_csv('zero_shot_COT_ASST_single_response_df.csv')

# %% [markdown]
# ### Response Generation for Zero Shot COT with no Process Logic with SCT input

# %%
zero_shot_NO_STEPS_COT_SYS_single_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_1_Generated_Summary
    query = row.Query
    prompt = zero_shot_prompt_SINGLE(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = ZERO_NO_STEPS_COT_SINGLE_generate_report_with_query(text, model,query,prompt)
    response_text_2 = ZERO_NO_STEPS_COT_SINGLE_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_shot_NO_STEPS_COT_SYS_single_response_df.loc[-1] = ref_row
    zero_shot_NO_STEPS_COT_SYS_single_response_df.index = zero_shot_NO_STEPS_COT_SYS_single_response_df.index + 1  #shift index
    zero_shot_NO_STEPS_COT_SYS_single_response_df = zero_shot_NO_STEPS_COT_SYS_single_response_df.sort_index()  #sort by index

# %%
zero_shot_NO_STEPS_COT_SYS_single_response_df.to_csv('zero_shot_NO_STEPS_COT_SYS_single_response_df.csv')

# %% [markdown]
# ### Response Generation for Zero Shot COT with Process Logic and Prompt Examples in System role prompting with SCT input

# %%
zero_STEP_WITH_EX_COT_SYS_single_response_df = pd.DataFrame(columns=['query','model_response','zero_shot_response_1','zero_shot_response_1_score','zero_shot_response_2','zero_shot_response_2_score','avg_score'])

for index ,row in testprompt_df.iterrows():
    text = row.Modified_1_Generated_Summary
    query = row.Query
    prompt = zero_shot_prompt_SINGLE(query)
    model_response = row.Model_Ranking_List_Output
    zero_shot_response_1_score = ''
    zero_shot_response_2_score = ''
    avg_score = ''
    
    response_text_1 = ZERO_STEP_WITH_EX_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt)
    response_text_2 = ZERO_STEP_WITH_EX_SYSTEM_COT_SINGLE_generate_report_with_query(text, model,query,prompt)

    ref_row = [query , 
               model_response, 
               response_text_1, 
               zero_shot_response_1_score, 
               response_text_2, 
               zero_shot_response_2_score, 
               avg_score,
               ]
    
    zero_STEP_WITH_EX_COT_SYS_single_response_df.loc[-1] = ref_row
    zero_STEP_WITH_EX_COT_SYS_single_response_df.index = zero_STEP_WITH_EX_COT_SYS_single_response_df.index + 1  #shift index
    zero_STEP_WITH_EX_COT_SYS_single_response_df = zero_STEP_WITH_EX_COT_SYS_single_response_df.sort_index()  #sort by index

# %%
zero_STEP_WITH_EX_COT_SYS_single_response_df.to_csv('zero_STEP_WITH_EX_COT_SYS_single_response_df.csv')

# %% [markdown]
# ### Metrics Evaluation for COT in User / System / Assistant Roles

# %%
# few5_shot_single_response_df = pd.read_csv('FinalTest_few5_shot_single_response_df.csv')
# few5_shot_multi_response_df = pd.read_csv('FinalTest_few5_shot_multi_response_df.csv')
# one_shot_single_response_df = pd.read_csv('FinalTest_one_shot_single_response_df.csv')
# one_shot_multi_response_df = pd.read_csv('FinalTest_one_shot_multi_response_df.csv')
# zero_shot_single_response_df = pd.read_csv('FinalTest_zero_shot_single_response_df.csv')
# zero_shot_multi_response_df = pd.read_csv('FinalTest_zero_shot_multi_response_df.csv')

# %%
# Response Dataframes from previous sections

response_df_list= [zero_shot_COT_USER_single_response_df,zero_shot_COT_SYS_single_response_df,zero_shot_COT_ASST_single_response_df]
response_df_list_names =['zero_shot_COT_USER_single_response_df','zero_shot_COT_SYS_single_response_df','zero_shot_COT_ASST_single_response_df']

# %% [markdown]
# #### Getting ROUGE Scores

# %%
## Rouge Scores
AllRouge_Scores = pd.DataFrame()
AllRouge_Scores = pd.DataFrame(columns=['Prompt Engineering Technique','rouge-1-r','rouge-1-p','rouge-1-f','rouge-2-r','rouge-2-p','rouge-2-f','rouge-l-r','rouge-l-p','rouge-l-f'])

# llm_model = ['phi3:latest','llama3.1:latest']
for response_df_index in range(len(response_df_list)): 
    Response_cols = list(filter(lambda x: (('score' not in x) and ('shot_response' in x)) == True, list(response_df_list[response_df_index].columns)))
    print('Response_cols : ',Response_cols)
    ModelSummary_col = 'model_response'
    technique_name = response_df_list_names[response_df_index]
    print('technique_name : ',technique_name)
    
    
    response_df_counter=1
    for Response_col in Response_cols:
        test_rouge_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
        test_rouge_df[Response_col] = test_rouge_df[Response_col].replace('', np.nan)
        test_rouge_df = test_rouge_df.dropna(subset=[Response_col])
        test_rouge_df = test_rouge_df.reset_index(drop=True)
        
        if response_df_counter ==1:
            rouge_scores_1 = eval_metrics.get_rouge_scores(test_rouge_df[ModelSummary_col],test_rouge_df[Response_col])
        else:
            rouge_scores_2 = eval_metrics.get_rouge_scores(test_rouge_df[ModelSummary_col],test_rouge_df[Response_col])
        response_df_counter+=1
    
    print('rouge_scores_1 : ',rouge_scores_1)
    print('rouge_scores_2 : ',rouge_scores_2)
    
    ref_row = [technique_name , 
               (rouge_scores_1['rouge-1']['r'] + rouge_scores_2['rouge-1']['r'])/2, 
               (rouge_scores_1['rouge-1']['p'] + rouge_scores_2['rouge-1']['p'])/2, 
               (rouge_scores_1['rouge-1']['f'] + rouge_scores_2['rouge-1']['f'])/2, 
               (rouge_scores_1['rouge-2']['r'] + rouge_scores_2['rouge-2']['r'])/2, 
               (rouge_scores_1['rouge-2']['p'] + rouge_scores_2['rouge-2']['p'])/2, 
               (rouge_scores_1['rouge-2']['f'] + rouge_scores_2['rouge-2']['f'])/2,
               (rouge_scores_1['rouge-l']['r'] + rouge_scores_2['rouge-l']['r'])/2, 
               (rouge_scores_1['rouge-l']['p'] + rouge_scores_2['rouge-l']['p'])/2, 
               (rouge_scores_1['rouge-l']['f'] + rouge_scores_2['rouge-l']['f'])/2
               ]
    
    print('ref_row : ',ref_row)
    
    AllRouge_Scores.loc[-1] = ref_row
    AllRouge_Scores.index = AllRouge_Scores.index + 1  #shift index
    AllRouge_Scores = AllRouge_Scores.sort_index()  #sort by index
# Out:
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_COT_USER_single_response_df
# rouge_scores_1 :  {'rouge-1': {'r': 0.3062269862540795, 'p': 0.5376007177451315, 'f': 0.3839745372922772}, 'rouge-2': {'r': 0.1393791637879232, 'p': 0.2869914692756151, 'f': 0.18407781474189808}, 'rouge-l': {'r': 0.2874459362286831, 'p': 0.5053966198082258, 'f': 0.3606219989747266}}
# rouge_scores_2 :  {'rouge-1': {'r': 0.30210425535773167, 'p': 0.5071431430242033, 'f': 0.37506237419751337}, 'rouge-2': {'r': 0.13281466166382, 'p': 0.25585478766122416, 'f': 0.17261111446726743}, 'rouge-l': {'r': 0.2843987674286079, 'p': 0.47978078125829765, 'f': 0.3537967140738487}}
# ref_row :  ['zero_shot_COT_USER_single_response_df', 0.3041656208059056, 0.5223719303846674, 0.3795184557448953, 0.1360969127258716, 0.27142312846841965, 0.17834446460458275, 0.2859223518286455, 0.49258870053326176, 0.35720935652428765]
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_COT_SYS_single_response_df
# rouge_scores_1 :  {'rouge-1': {'r': 0.31590918677745644, 'p': 0.5450881829072978, 'f': 0.3909174851982463}, 'rouge-2': {'r': 0.14740294271888632, 'p': 0.29055796945460594, 'f': 0.1894264786399807}, 'rouge-l': {'r': 0.2961751130404739, 'p': 0.5106799405353938, 'f': 0.3662742182994153}}
# rouge_scores_2 :  {'rouge-1': {'r': 0.3071770330557514, 'p': 0.5282408688465055, 'f': 0.3838351094656557}, 'rouge-2': {'r': 0.1379713304668693, 'p': 0.2815860692386612, 'f': 0.18219142842909636}, 'rouge-l': {'r': 0.29105361604581553, 'p': 0.5012065553845039, 'f': 0.3638455556752674}}
# ref_row :  ['zero_shot_COT_SYS_single_response_df', 0.31154310991660394, 0.5366645258769016, 0.387376297331951, 0.1426871365928778, 0.28607201934663357, 0.18580895353453852, 0.2936143645431447, 0.5059432479599488, 0.3650598869873414]
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_COT_ASST_single_response_df
# rouge_scores_1 :  {'rouge-1': {'r': 0.29758249881546744, 'p': 0.5117298761775181, 'f': 0.36659689386937366}, 'rouge-2': {'r': 0.1341609199827712, 'p': 0.2554053262746358, 'f': 0.17090978156753237}, 'rouge-l': {'r': 0.28440261212398055, 'p': 0.4893713758787818, 'f': 0.35053668796280035}}
# rouge_scores_2 :  {'rouge-1': {'r': 0.27107402125260693, 'p': 0.5064677897807324, 'f': 0.3432451919304292}, 'rouge-2': {'r': 0.12071768621559711, 'p': 0.24995696918554183, 'f': 0.15875115257536182}, 'rouge-l': {'r': 0.25887128535807535, 'p': 0.4802320627711746, 'f': 0.32737010369308067}}
# ref_row :  ['zero_shot_COT_ASST_single_response_df', 0.2843282600340372, 0.5090988329791253, 0.35492104289990145, 0.12743930309918416, 0.2526811477300888, 0.1648304670714471, 0.27163694874102795, 0.4848017193249782, 0.3389533958279405]

# %%
AllRouge_Scores
# Out:
#             Prompt Engineering Technique  rouge-1-r  rouge-1-p  rouge-1-f  \
# 0  zero_shot_COT_ASST_single_response_df   0.284328   0.509099   0.354921
# 1   zero_shot_COT_SYS_single_response_df   0.311543   0.536665   0.387376
# 2  zero_shot_COT_USER_single_response_df   0.304166   0.522372   0.379518
#
#    rouge-2-r  rouge-2-p  rouge-2-f  rouge-l-r  rouge-l-p  rouge-l-f
# 0   0.127439   0.252681   0.164830   0.271637   0.484802   0.338953
# 1   0.142687   0.286072   0.185809   0.293614   0.505943   0.365060
# 2   0.136097   0.271423   0.178344   0.285922   0.492589   0.357209

# %% [markdown]
# #### Getting BERTScore

# %%
import statistics

# %%
bertscore = load("bertscore")

# %%
## BERT Scores
AllBERT_Scores = pd.DataFrame()
AllBERT_Scores = pd.DataFrame(columns=['Prompt Engineering Technique','Precision Mean','Precision Stddev','Recall Mean','Recall Stddev','F1 Score Mean','F1 Score Stddev','hashcode'])

# llm_model = ['phi3:latest','llama3.1:latest']
for response_df_index in range(len(response_df_list)): 
    Response_cols = list(filter(lambda x: (('score' not in x) and ('shot_response' in x)) == True, list(response_df_list[response_df_index].columns)))
    print('Response_cols : ',Response_cols)
    ModelSummary_col = 'model_response'
    technique_name = response_df_list_names[response_df_index]
    print('technique_name : ',technique_name)
    
    
    response_df_counter=1
    for Response_col in Response_cols:
        
        if response_df_counter ==1:
            test_bert_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
            test_bert_df[Response_col] = test_bert_df[Response_col].replace('', np.nan)
            test_bert_df = test_bert_df.dropna(subset=[Response_col])
            test_bert_df = test_bert_df.reset_index(drop=True)
            
            BERT_Scores_1 = bertscore.compute(predictions=test_bert_df[Response_col], references=test_bert_df[ModelSummary_col], lang="en")
            precision_mean_1 = statistics.mean(BERT_Scores_1['precision'])
            precision_stdev_1 = statistics.stdev(BERT_Scores_1['precision'])
            recall_mean_1 = statistics.mean(BERT_Scores_1['recall'])
            recall_stdev_1 = statistics.stdev(BERT_Scores_1['recall'])
            f1_mean_1 = statistics.mean(BERT_Scores_1['f1'])
            f1_stdev_1 = statistics.stdev(BERT_Scores_1['f1'])
            hash_code_1 = BERT_Scores_1['hashcode']
        else:
            test_bert_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
            test_bert_df[Response_col] = test_bert_df[Response_col].replace('', np.nan)
            test_bert_df = test_bert_df.dropna(subset=[Response_col])
            test_bert_df = test_bert_df.reset_index(drop=True)
            
            BERT_Scores_2 = bertscore.compute(predictions=test_bert_df[Response_col], references=test_bert_df[ModelSummary_col], lang="en")
            precision_mean_2 = statistics.mean(BERT_Scores_2['precision'])
            precision_stdev_2 = statistics.stdev(BERT_Scores_2['precision'])
            recall_mean_2 = statistics.mean(BERT_Scores_2['recall'])
            recall_stdev_2 = statistics.stdev(BERT_Scores_2['recall'])
            f1_mean_2 = statistics.mean(BERT_Scores_2['f1'])
            f1_stdev_2 = statistics.stdev(BERT_Scores_2['f1'])
            hash_code_2 = BERT_Scores_2['hashcode']
        response_df_counter+=1
        
    
    print('BERT_Scores_1 : ',BERT_Scores_1)
    print('BERT_Scores_2 : ',BERT_Scores_2)
    
    ref_row = [technique_name , 
               (precision_mean_1 + precision_mean_2)/2,
               (precision_stdev_1 + precision_stdev_2)/2,
               (recall_mean_1 + recall_mean_2)/2,
               (recall_stdev_1 + recall_stdev_2)/2,
               (f1_mean_1 + f1_mean_2)/2,
               (f1_stdev_1 + f1_stdev_2)/2,
               hash_code_1
               ]
    
    print('ref_row : ',ref_row)
    
    AllBERT_Scores.loc[-1] = ref_row
    AllBERT_Scores.index = AllBERT_Scores.index + 1  #shift index
    AllBERT_Scores = AllBERT_Scores.sort_index()  #sort by index
# Out:
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_COT_USER_single_response_df
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERT_Scores_1 :  {'precision': [0.8801832795143127, 0.8891693949699402, 0.8951738476753235, 0.7938793897628784, 0.8827404379844666, 0.8217037320137024, 0.8735415935516357, 0.8672705888748169, 0.9008064866065979, 0.8750600218772888], 'recall': [0.8667184710502625, 0.8819510340690613, 0.8548541069030762, 0.7945992350578308, 0.8598701357841492, 0.8148654103279114, 0.8723720908164978, 0.85444176197052, 0.8646509647369385, 0.8777549862861633], 'f1': [0.8733989596366882, 0.885545551776886, 0.8745495676994324, 0.7942392230033875, 0.8711552023887634, 0.8182702660560608, 0.8729564547538757, 0.8608083724975586, 0.8823585510253906, 0.8764054179191589], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# BERT_Scores_1 :  {'precision': [0.8117539882659912, 0.8771041631698608, 0.8866293430328369, 0.8005514740943909, 0.8928024172782898, 0.7966721057891846, 0.9070638418197632, 0.8565407991409302, 0.8690372705459595, 0.8650258779525757], 'recall': [0.7997085452079773, 0.8733800053596497, 0.8520616888999939, 0.8542837500572205, 0.8583130836486816, 0.7735961675643921, 0.873397946357727, 0.8105134963989258, 0.8636608123779297, 0.8739199638366699], 'f1': [0.8056861758232117, 0.8752380609512329, 0.8690018653869629, 0.826545238494873, 0.8752180933952332, 0.7849645614624023, 0.8899126052856445, 0.8328917622566223, 0.866340696811676, 0.8694501519203186], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# BERT_Scores_2 :  {'precision': [0.8077484965324402, 0.8903778791427612, 0.869353711605072, 0.8771123886108398, 0.8826051950454712, 0.8381212949752808, 0.9048649668693542, 0.7342043519020081, 0.8851161003112793, 0.8798448443412781], 'recall': [0.7880205512046814, 0.8895578384399414, 0.845155656337738, 0.8541147708892822, 0.8672800064086914, 0.7759542465209961, 0.8786537051200867, 0.7516109943389893, 0.8713970184326172, 0.8721916675567627], 'f1': [0.7977625727653503, 0.889967679977417, 0.8570839166641235, 0.8654608130455017, 0.8748754858970642, 0.8058405518531799, 0.8915667533874512, 0.7428057789802551, 0.8782030344009399, 0.8760015368461609], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# ref_row :  ['zero_shot_COT_ASST_single_response_df', 0.8566265255212784, 0.04553168754801824, 0.8413385957479477, 0.042279563634230063, 0.848740866780281, 0.0420317682560231, 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)']

# %%
AllBERT_Scores
# Out:
#             Prompt Engineering Technique  Precision Mean  Precision Stddev  \
# 0  zero_shot_COT_ASST_single_response_df        0.856627          0.045532
# 1   zero_shot_COT_SYS_single_response_df        0.870929          0.025511
# 2  zero_shot_COT_USER_single_response_df        0.862280          0.027420
#
#    Recall Mean  Recall Stddev  F1 Score Mean  F1 Score Stddev  \
# 0     0.841339       0.042280       0.848741         0.042032
# 1     0.858232       0.022419       0.864475         0.022721
# 2     0.855031       0.020792       0.858580         0.023317
#
#                                             hashcode
# 0  roberta-large_L17_no-idf_version=0.3.12(hug_tr...
# 1  roberta-large_L17_no-idf_version=0.3.12(hug_tr...
# 2  roberta-large_L17_no-idf_version=0.3.12(hug_tr...

# %% [markdown]
# #### Metrics Evaluation 2 (COT with Prompt Examples vs COT with no Process Logic)

# %% [markdown]
# #### Response DF Initialization

# %%
response_df_list= [zero_STEP_WITH_EX_COT_SYS_single_response_df,zero_shot_NO_STEPS_COT_SYS_single_response_df]
response_df_list_names =['zero_STEP_WITH_EX_COT_SYS_single_response_df','zero_shot_NO_STEPS_COT_SYS_single_response_df']

# %%
## Rouge Scores
AllRouge_Scores = pd.DataFrame()
AllRouge_Scores = pd.DataFrame(columns=['Prompt Engineering Technique','rouge-1-r','rouge-1-p','rouge-1-f','rouge-2-r','rouge-2-p','rouge-2-f','rouge-l-r','rouge-l-p','rouge-l-f'])

# llm_model = ['phi3:latest','llama3.1:latest']
for response_df_index in range(len(response_df_list)): 
    Response_cols = list(filter(lambda x: (('score' not in x) and ('shot_response' in x)) == True, list(response_df_list[response_df_index].columns)))
    print('Response_cols : ',Response_cols)
    ModelSummary_col = 'model_response'
    technique_name = response_df_list_names[response_df_index]
    print('technique_name : ',technique_name)
    
    
    response_df_counter=1
    for Response_col in Response_cols:
        test_rouge_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
        test_rouge_df[Response_col] = test_rouge_df[Response_col].replace('', np.nan)
        test_rouge_df = test_rouge_df.dropna(subset=[Response_col])
        test_rouge_df = test_rouge_df.reset_index(drop=True)
        
        if response_df_counter ==1:
            rouge_scores_1 = eval_metrics.get_rouge_scores(test_rouge_df[ModelSummary_col],test_rouge_df[Response_col])
        else:
            rouge_scores_2 = eval_metrics.get_rouge_scores(test_rouge_df[ModelSummary_col],test_rouge_df[Response_col])
        response_df_counter+=1
    
    print('rouge_scores_1 : ',rouge_scores_1)
    print('rouge_scores_2 : ',rouge_scores_2)
    
    ref_row = [technique_name , 
               (rouge_scores_1['rouge-1']['r'] + rouge_scores_2['rouge-1']['r'])/2, 
               (rouge_scores_1['rouge-1']['p'] + rouge_scores_2['rouge-1']['p'])/2, 
               (rouge_scores_1['rouge-1']['f'] + rouge_scores_2['rouge-1']['f'])/2, 
               (rouge_scores_1['rouge-2']['r'] + rouge_scores_2['rouge-2']['r'])/2, 
               (rouge_scores_1['rouge-2']['p'] + rouge_scores_2['rouge-2']['p'])/2, 
               (rouge_scores_1['rouge-2']['f'] + rouge_scores_2['rouge-2']['f'])/2,
               (rouge_scores_1['rouge-l']['r'] + rouge_scores_2['rouge-l']['r'])/2, 
               (rouge_scores_1['rouge-l']['p'] + rouge_scores_2['rouge-l']['p'])/2, 
               (rouge_scores_1['rouge-l']['f'] + rouge_scores_2['rouge-l']['f'])/2
               ]
    
    print('ref_row : ',ref_row)
    
    AllRouge_Scores.loc[-1] = ref_row
    AllRouge_Scores.index = AllRouge_Scores.index + 1  #shift index
    AllRouge_Scores = AllRouge_Scores.sort_index()  #sort by index
# Out:
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_STEP_WITH_EX_COT_SYS_single_response_df
# rouge_scores_1 :  {'rouge-1': {'r': 0.267791335060787, 'p': 0.5613288241248591, 'f': 0.35847311616915356}, 'rouge-2': {'r': 0.11173843703050021, 'p': 0.2897038509366442, 'f': 0.1590277633896821}, 'rouge-l': {'r': 0.2526823187490778, 'p': 0.5316053663963655, 'f': 0.3387032020363973}}
# rouge_scores_2 :  {'rouge-1': {'r': 0.2702081971594198, 'p': 0.5265217169526689, 'f': 0.34927079248255327}, 'rouge-2': {'r': 0.11111821051682447, 'p': 0.2456926553054249, 'f': 0.1515749607192916}, 'rouge-l': {'r': 0.2494703429583971, 'p': 0.483726914445379, 'f': 0.3223360634411337}}
# ref_row :  ['zero_STEP_WITH_EX_COT_SYS_single_response_df', 0.2689997661101034, 0.543925270538764, 0.3538719543258534, 0.11142832377366234, 0.26769825312103457, 0.15530136205448686, 0.2510763308537375, 0.5076661404208722, 0.3305196327387655]
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_NO_STEPS_COT_SYS_single_response_df
# rouge_scores_1 :  {'rouge-1': {'r': 0.3488857541138485, 'p': 0.5895748177547704, 'f': 0.4335528411222498}, 'rouge-2': {'r': 0.1736537396323888, 'p': 0.34219509389479763, 'f': 0.2270558780974262}, 'rouge-l': {'r': 0.3298027408864496, 'p': 0.5586866482549834, 'f': 0.4102500341099649}}
# rouge_scores_2 :  {'rouge-1': {'r': 0.3182892542311918, 'p': 0.5965702228606758, 'f': 0.4091329472937041}, 'rouge-2': {'r': 0.14701052090312944, 'p': 0.33287043710787156, 'f': 0.20036038255323102}, 'rouge-l': {'r': 0.2979960544062379, 'p': 0.5599810567536968, 'f': 0.3833890683410407}}
# ref_row :  ['zero_shot_NO_STEPS_COT_SYS_single_response_df', 0.33358750417252014, 0.5930725203077232, 0.42134289420797694, 0.1603321302677591, 0.3375327655013346, 0.2137081303253286, 0.3138993976463438, 0.5593338525043401, 0.39681955122550283]

# %%
AllRouge_Scores
# Out:
#                     Prompt Engineering Technique  rouge-1-r  rouge-1-p  \
# 0  zero_shot_NO_STEPS_COT_SYS_single_response_df   0.333588   0.593073
# 1   zero_STEP_WITH_EX_COT_SYS_single_response_df   0.269000   0.543925
#
#    rouge-1-f  rouge-2-r  rouge-2-p  rouge-2-f  rouge-l-r  rouge-l-p  rouge-l-f
# 0   0.421343   0.160332   0.337533   0.213708   0.313899   0.559334    0.39682
# 1   0.353872   0.111428   0.267698   0.155301   0.251076   0.507666    0.33052

# %% [markdown]
# #### Getting BERTScore

# %%
## BERT Scores
AllBERT_Scores = pd.DataFrame()
AllBERT_Scores = pd.DataFrame(columns=['Prompt Engineering Technique','Precision Mean','Precision Stddev','Recall Mean','Recall Stddev','F1 Score Mean','F1 Score Stddev','hashcode'])

# llm_model = ['phi3:latest','llama3.1:latest']
for response_df_index in range(len(response_df_list)): 
    Response_cols = list(filter(lambda x: (('score' not in x) and ('shot_response' in x)) == True, list(response_df_list[response_df_index].columns)))
    print('Response_cols : ',Response_cols)
    ModelSummary_col = 'model_response'
    technique_name = response_df_list_names[response_df_index]
    print('technique_name : ',technique_name)
    
    
    response_df_counter=1
    for Response_col in Response_cols:
        
        if response_df_counter ==1:
            test_bert_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
            test_bert_df[Response_col] = test_bert_df[Response_col].replace('', np.nan)
            test_bert_df = test_bert_df.dropna(subset=[Response_col])
            test_bert_df = test_bert_df.reset_index(drop=True)
            
            BERT_Scores_1 = bertscore.compute(predictions=test_bert_df[Response_col], references=test_bert_df[ModelSummary_col], lang="en")
            precision_mean_1 = statistics.mean(BERT_Scores_1['precision'])
            precision_stdev_1 = statistics.stdev(BERT_Scores_1['precision'])
            recall_mean_1 = statistics.mean(BERT_Scores_1['recall'])
            recall_stdev_1 = statistics.stdev(BERT_Scores_1['recall'])
            f1_mean_1 = statistics.mean(BERT_Scores_1['f1'])
            f1_stdev_1 = statistics.stdev(BERT_Scores_1['f1'])
            hash_code_1 = BERT_Scores_1['hashcode']
        else:
            test_bert_df = response_df_list[response_df_index][[Response_col,ModelSummary_col]].copy(deep=True)
            test_bert_df[Response_col] = test_bert_df[Response_col].replace('', np.nan)
            test_bert_df = test_bert_df.dropna(subset=[Response_col])
            test_bert_df = test_bert_df.reset_index(drop=True)
            
            BERT_Scores_2 = bertscore.compute(predictions=test_bert_df[Response_col], references=test_bert_df[ModelSummary_col], lang="en")
            precision_mean_2 = statistics.mean(BERT_Scores_2['precision'])
            precision_stdev_2 = statistics.stdev(BERT_Scores_2['precision'])
            recall_mean_2 = statistics.mean(BERT_Scores_2['recall'])
            recall_stdev_2 = statistics.stdev(BERT_Scores_2['recall'])
            f1_mean_2 = statistics.mean(BERT_Scores_2['f1'])
            f1_stdev_2 = statistics.stdev(BERT_Scores_2['f1'])
            hash_code_2 = BERT_Scores_2['hashcode']
        response_df_counter+=1
        
    
    print('BERT_Scores_1 : ',BERT_Scores_1)
    print('BERT_Scores_2 : ',BERT_Scores_2)
    
    ref_row = [technique_name , 
               (precision_mean_1 + precision_mean_2)/2,
               (precision_stdev_1 + precision_stdev_2)/2,
               (recall_mean_1 + recall_mean_2)/2,
               (recall_stdev_1 + recall_stdev_2)/2,
               (f1_mean_1 + f1_mean_2)/2,
               (f1_stdev_1 + f1_stdev_2)/2,
               hash_code_1
               ]
    
    print('ref_row : ',ref_row)
    
    AllBERT_Scores.loc[-1] = ref_row
    AllBERT_Scores.index = AllBERT_Scores.index + 1  #shift index
    AllBERT_Scores = AllBERT_Scores.sort_index()  #sort by index
# Out:
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_STEP_WITH_EX_COT_SYS_single_response_df
# BERT_Scores_1 :  {'precision': [0.8748749494552612, 0.8916327357292175, 0.9043223857879639, 0.8711660504341125, 0.8965637683868408, 0.8562110662460327, 0.8699185252189636, 0.8661855459213257, 0.9063277840614319, 0.8756944537162781], 'recall': [0.8488946557044983, 0.8533327579498291, 0.8681201934814453, 0.8589116334915161, 0.8532718420028687, 0.8507874011993408, 0.8593361377716064, 0.8591965436935425, 0.8580129742622375, 0.8469337224960327], 'f1': [0.8616889715194702, 0.8720623850822449, 0.8858515620231628, 0.8649954199790955, 0.8743822574615479, 0.8534905910491943, 0.8645949363708496, 0.8626769185066223, 0.8815088272094727, 0.8610740303993225], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# BERT_Scores_2 :  {'precision': [0.875113308429718, 0.9153162837028503, 0.8849759101867676, 0.8580702543258667, 0.874768078327179, 0.8383445143699646, 0.8982372879981995, 0.8544772863388062, 0.914015531539917, 0.8876309990882874], 'recall': [0.8576751351356506, 0.8852801322937012, 0.8505675196647644, 0.8427568674087524, 0.8464216589927673, 0.7723644971847534, 0.8598189353942871, 0.8571126461029053, 0.8774328231811523, 0.8542784452438354], 'f1': [0.866306483745575, 0.9000476598739624, 0.867430567741394, 0.8503445982933044, 0.8603614568710327, 0.8040031790733337, 0.8786083459854126, 0.8557929396629333, 0.8953506350517273, 0.8706353902816772], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# ref_row :  ['zero_STEP_WITH_EX_COT_SYS_single_response_df', 0.8806923359632493, 0.02121979779950238, 0.8530253261327743, 0.01833242880032577, 0.8665603578090668, 0.018363844357678523, 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)']
# Response_cols :  ['zero_shot_response_1', 'zero_shot_response_2']
# technique_name :  zero_shot_NO_STEPS_COT_SYS_single_response_df
# BERT_Scores_1 :  {'precision': [0.892072319984436, 0.9227606654167175, 0.9001781344413757, 0.910861611366272, 0.8999438285827637, 0.8559510111808777, 0.8957118988037109, 0.8630733489990234, 0.8978742361068726, 0.8954047560691833], 'recall': [0.8828482031822205, 0.9017627835273743, 0.8633900284767151, 0.8866649270057678, 0.8578510880470276, 0.846998393535614, 0.8677399158477783, 0.8586637377738953, 0.8735620379447937, 0.882453441619873], 'f1': [0.8874363303184509, 0.9121409058570862, 0.8814003467559814, 0.8986003994941711, 0.8783934712409973, 0.8514511585235596, 0.8815040588378906, 0.8608628511428833, 0.8855513334274292, 0.8888819217681885], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# BERT_Scores_2 :  {'precision': [0.8923528790473938, 0.9069089889526367, 0.91767418384552, 0.9015856385231018, 0.8863586187362671, 0.8329416513442993, 0.8824582695960999, 0.8651805520057678, 0.9013354182243347, 0.87333744764328], 'recall': [0.8773555159568787, 0.8885831832885742, 0.8674750328063965, 0.8741359710693359, 0.8336377739906311, 0.8240271806716919, 0.8747607469558716, 0.8499614000320435, 0.8735592365264893, 0.8730533719062805], 'f1': [0.8847906589508057, 0.8976525664329529, 0.8918687701225281, 0.8876486420631409, 0.8591901659965515, 0.8284604549407959, 0.8785926103591919, 0.8575034737586975, 0.8872299790382385, 0.8731953501701355], 'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)'}
# ref_row :  ['zero_shot_NO_STEPS_COT_SYS_single_response_df', 0.8896982729434967, 0.022237841985011157, 0.8679241985082626, 0.018619226807306363, 0.8786177724599837, 0.01906252418414474, 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.48.2)']

# %%
AllBERT_Scores
# Out:
#                     Prompt Engineering Technique  Precision Mean  \
# 0  zero_shot_NO_STEPS_COT_SYS_single_response_df        0.889698
# 1   zero_STEP_WITH_EX_COT_SYS_single_response_df        0.880692
#
#    Precision Stddev  Recall Mean  Recall Stddev  F1 Score Mean  \
# 0          0.022238     0.867924       0.018619       0.878618
# 1          0.021220     0.853025       0.018332       0.866560
#
#    F1 Score Stddev                                           hashcode
# 0         0.019063  roberta-large_L17_no-idf_version=0.3.12(hug_tr...
# 1         0.018364  roberta-large_L17_no-idf_version=0.3.12(hug_tr...
